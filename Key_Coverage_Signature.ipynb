# %% [markdown]
# # Signature Based Labelling
# ------------------

# %% [markdown]
# - Apply Sigma, ET-Pro, etc Rules to the dataset.

# %% [markdown]
# # Preparation

# %%
import pandas as pd, numpy as np, networkx as nx
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import chi2
from sklearn.linear_model.logistic import LogisticRegression
pd.options.display.max_columns = 500
pd.options.display.max_colwidth = 500
# Out:
# /home/jake/miniconda3/envs/py3msc/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.linear_model.logistic module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df_zeek = pd.read_json("combined_zeek.log", lines = True)
df_zeek.replace('nan', np.nan, inplace=True)
print(type(df_zeek))
print(df_zeek.shape)
#print(df_zeek.EventID.value_counts())
df_zeek.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (2140, 148)
#   @stream              @system @proc            ts                 uid  \
# 0    conn  bobs.bigwheel.local  zeek  1.588205e+09  Cvf4XX17hSAgXDdGEd
# 1    conn  bobs.bigwheel.local  zeek  1.588205e+09  CJ21Le4zsTUcyKKi98
# 2    conn  bobs.bigwheel.local  zeek  1.588205e+09  CnOP7t1eGGHf6LFfuk
# 3    conn  bobs.bigwheel.local  zeek  1.588205e+09  CvxbPE3MuO7boUdSc8
# 4    conn  bobs.bigwheel.local  zeek  1.588205e+09  CuRbE21APSQo2qd6rk
#
#   id_orig_h  id_orig_p   id_resp_h  id_resp_p proto         service  \
# 0  10.0.1.6    54243.0    10.0.0.4       53.0   udp             dns
# 1  10.0.1.6    56880.0    10.0.0.4      445.0   tcp  gssapi,smb,krb
# 2  10.0.1.6    65108.0    10.0.0.4       53.0   udp             dns
# 3  10.0.1.6      138.0  10.0.1.255      138.0   udp             NaN
# 4  10.0.1.6      123.0    10.0.0.4      123.0   udp             NaN
#
#     duration  orig_bytes  resp_bytes conn_state  missed_bytes  history  \
# ...

# %%
df_label = pd.read_json('./df_labelled_coalesce.json', lines=True)
df_label['TP_Binary'] = df_label.TP_Label!='0'
df_label.replace('-', np.nan, inplace=True)
print(type(df_label))
print(df_label.shape)
print(df_label.EventID.value_counts())
df_label.head(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (198760, 390)
# 12       61158
# 10       39286
# 7        20259
# 13       17542
# 4658     10973
#          ...
# 172          1
# 46           1
# 50103        1
# 306          1
# 41           1
# Name: EventID, Length: 165, dtype: int64
#                  @timestamp  @version                            Category  \
# 0  2020-05-02T03:20:47.897Z         1  Kerberos Service Ticket Operations
#
#     Channel  EventID    EventReceivedTime            EventTime      EventType  \
# 0  Security     4769  2020-05-01 23:20:47  2020-05-01 23:20:46  AUDIT_SUCCESS
#
#    ExecutionProcessID               Hostname        IpAddress IpPort  \
# 0                 704  NEWYORK.dmevals.local  ::ffff:10.0.1.4  49764
#
#               Keywords                               LogonGuid  \
# 0 -9214364837600034816  {fe5dd628-f256-ba1b-3123-bfa971bd494a}
#
# ...

# %%
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#    In [9]: result = pd.concat([df1, df4], axis=1, sort=False)
df_label = df_label.append(df_zeek, ignore_index=True, sort=False)

# %%
df_label.shape
# Out:
# (200900, 536)

# %%
df_label.head(1)
# Out:
#                  @timestamp  @version                            Category  \
# 0  2020-05-02T03:20:47.897Z       1.0  Kerberos Service Ticket Operations
#
#     Channel  EventID    EventReceivedTime            EventTime      EventType  \
# 0  Security   4769.0  2020-05-01 23:20:47  2020-05-01 23:20:46  AUDIT_SUCCESS
#
#    ExecutionProcessID               Hostname        IpAddress IpPort  \
# 0               704.0  NEWYORK.dmevals.local  ::ffff:10.0.1.4  49764
#
#        Keywords                               LogonGuid  \
# 0 -9.214365e+18  {fe5dd628-f256-ba1b-3123-bfa971bd494a}
#
# ...

# %%
df_label.tail(1)
# Out:
#        @timestamp  @version Category Channel  EventID EventReceivedTime  \
# 200899        NaN       NaN      NaN     NaN      NaN               NaN
#
#        EventTime EventType  ExecutionProcessID Hostname IpAddress IpPort  \
# 200899       NaN       NaN                 NaN      NaN       NaN    NaN
#
#         Keywords LogonGuid Message Opcode  OpcodeValue ProviderGuid  \
# 200899       NaN       NaN     NaN    NaN          NaN          NaN
#
#         RecordNumber ServiceName ServiceSid Severity  SeverityValue  \
# 200899           NaN         NaN        NaN      NaN            NaN
#
#        SourceModuleName SourceModuleType SourceName Status TargetDomainName  \
# 200899              NaN              NaN        NaN    NaN              NaN
#
#        TargetUserName  Task  ThreadID TicketEncryptionType TicketOptions  \
# 200899            NaN   NaN       NaN                  NaN           NaN
#
#         TransmittedServices  Version host  port tags TP_Label Action  \
# ...

# %% [markdown]
# ## Normalize Timestamp, IP/Port Columns
# ------------------

# %%
df_label['time_stamp'] = df_label['@timestamp'].apply(lambda x: (pd.Timestamp(x)))

# %%
df_label['time_stamp'] = df_label['time_stamp'].fillna(df_label['ts'].apply(lambda x: (pd.to_datetime(x, unit='s', utc=True))))

# %%
# Transform Host Data - Similar Data to Single Columns
df_label['Destination_IP'] = df_label['DestinationIp']
df_label['Destination_IP'] = df_label['Destination_IP'].fillna(df_label['DestAddress'])
df_label['Source_IP'] = df_label['IpAddress']
df_label['Source_IP'] = df_label['Source_IP'].fillna(df_label['SourceIp'])
df_label['Source_IP'] = df_label['Source_IP'].fillna(df_label['SourceAddress'])
df_label['Source_Port'] = df_label['IpPort']
df_label['Source_Port'] = df_label['Source_Port'].fillna(df_label['SourcePort'])
df_label['Destination_Port'] = df_label['DestinationPort']
df_label['Destination_Port'] = df_label['Destination_Port'].fillna(df_label['DestPort'])

# %%
# Transform Network Data - Similar Data to Single Columns
df_label['Source_IP'] = df_label['Source_IP'].fillna(df_label['id_orig_h'])
df_label['Source_Port'] = df_label['Source_Port'].fillna(df_label['id_orig_p'])
df_label['Destination_IP'] = df_label['Destination_IP'].fillna(df_label['id_resp_h'])
df_label['Destination_Port'] = df_label['Destination_Port'].fillna(df_label['id_resp_p'])

# %% [markdown]
# # Windows Event Log Key Analysis

# %% [markdown]
# - Sysmon and most (enough) windows events are covered by either ProcessGuid or ProcessId + Hostname
# - Powershell logs are out... Future work, recommend incoporating a primary key in development?
#     - maybe translate between process creation events -> powershell events?
#     - might have to incorporate timestamp.
#     - Could bin the timestamp of all powershell activity between start-stop times of malicious processes.

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    display(df_label.loc[df_label.EventID.notna()][['EventID', 'ProcessGuid', 'ProcessId', 'Hostname', '@timestamp']].groupby('EventID').count().sort_values(by=['@timestamp'], ascending=False).head(20))
# Out:
#          ProcessGuid  ProcessId  Hostname  @timestamp
# EventID
# 12.0           61157      61157     61158       61158
# 10.0               0      39283     39286       39286
# 7.0            20259      20259     20259       20259
# 13.0           17541      17541     17542       17542
# 4658.0             0      10973     10973       10973
# 4103.0             0          0      7750        7750
# 4656.0             0       5497      5497        5497
# 4690.0             0       5471      5471        5471
# 4663.0             0       5337      5337        5337
# 800.0              0          0      5113        5113
# 5156.0             0       3163      3163        3163
# 5447.0             0       2587      2587        2587
# 5158.0             0       1896      1896        1896
# 4703.0             0       1802      1802        1802
# 11.0            1649       1649      1653        1653
# 3.0             1229       1229      1230        1230
# ...

# %%
df = df_label.loc[df_label.EventID == 4688].drop(columns='Message')
df[df.columns[~df.isnull().all()]].head(1)
# Out:
#                   @timestamp  @version          Category   Channel  EventID  \
# 40  2020-05-02T03:06:14.178Z       1.0  Process Creation  Security   4688.0
#
#       EventReceivedTime            EventTime      EventType  \
# 40  2020-05-01 23:06:14  2020-05-01 23:06:13  AUDIT_SUCCESS
#
#     ExecutionProcessID               Hostname      Keywords Opcode  \
# 40                 4.0  NEWYORK.dmevals.local -9.214365e+18   Info
#
#     OpcodeValue                            ProviderGuid  RecordNumber  \
# 40          0.0  {54849625-5478-4994-A5BA-3E3B0328C30D}      151599.0
#
#    Severity  SeverityValue SourceModuleName SourceModuleType  \
# 40     INFO            2.0         eventlog    im_msvistalog
#
#                              SourceName TargetDomainName TargetUserName  \
# 40  Microsoft-Windows-Security-Auditing              NaN            NaN
#
#        Task  ThreadID  Version                       host     port  \
# ...

# %%
df = df_label.loc[df_label.EventID == 1].drop(columns='Message')
df[df.columns[~df.isnull().all()]].head(1)
# Out:
#                    @timestamp  @version                               Channel  \
# 380  2020-05-02T03:14:20.302Z       1.0  Microsoft-Windows-Sysmon/Operational
#
#      EventID    EventReceivedTime            EventTime EventType  \
# 380      1.0  2020-05-01 23:14:20  2020-05-01 23:14:17      INFO
#
#      ExecutionProcessID                Hostname      Keywords  \
# 380              3484.0  SCRANTON.dmevals.local -9.223372e+18
#
#                                   LogonGuid Opcode  OpcodeValue  \
# 380  {47ab858c-dabe-5eac-f331-370000000000}    NaN          0.0
#
#                                ProviderGuid  RecordNumber Severity  \
# 380  {5770385F-C22A-43E0-BF4C-06F5698FFBD9}      387006.0     INFO
#
#      SeverityValue SourceModuleName SourceModuleType  \
# 380            2.0         eventlog    im_msvistalog
#
#                    SourceName Status  Task  ThreadID  Version  \
# 380  Microsoft-Windows-Sysmon    NaN   1.0    4588.0      5.0
#
# ...

# %%
# ExecutionProcessID doesn't seem to translate outside of the powershell logs.
# ThreatID wouldnt be specific enough... same for ActivityID
# UserID is a maybe..
df = df_label.loc[df_label.EventID == 4103].drop(columns='Message')
df[df.columns[~df.isnull().all()]].head(1)
# Out:
#                    @timestamp  @version            Category  \
# 167  2020-05-02T02:56:19.260Z       1.0  Executing Pipeline
#
#                                       Channel  EventID    EventReceivedTime  \
# 167  Microsoft-Windows-PowerShell/Operational   4103.0  2020-05-01 22:56:19
#
#                EventTime EventType  ExecutionProcessID  \
# 167  2020-05-01 22:56:18      INFO              5944.0
#
#                    Hostname  Keywords  \
# 167  SCRANTON.dmevals.local       0.0
#
#                                                    Opcode  OpcodeValue  \
# 167  To be used when operation is just executing a method         20.0
#
#                                ProviderGuid  RecordNumber Severity  \
# 167  {A0C1853B-5C40-4B15-8766-3CF1C58F985A}        8394.0     INFO
#
#      SeverityValue SourceModuleName SourceModuleType  \
# 167            2.0         eventlog    im_msvistalog
#
#                        SourceName   Task  ThreadID  Version  \
# ...

# %%
# This ThreadID doesn't hit on any ProcessGuids or ProcessIDs...
df = df_label.loc[df_label.ThreadID == 3388]
#df[df.columns[~df.isnull().all()]].head(100)
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    display(df[df.columns[~df.isnull().all()]][['EventID', 'ProcessGuid', 'ProcessId', 'Hostname', '@timestamp']].groupby('EventID').count().sort_values(by=['@timestamp'], ascending=False).head(20))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-eacc5dfd5f0a> in <module>
#       2 #df[df.columns[~df.isnull().all()]].head(100)
#       3 with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
# ----> 4     display(df[df.columns[~df.isnull().all()]][['EventID', 'ProcessGuid', 'ProcessId', 'Hostname', '@timestamp']].groupby('EventID').count().sort_values(by=['@timestamp'], ascending=False).head(20))
#
# ~/miniconda3/envs/py3msc/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ...

# %%
# This ThreadID doesn't hit on any ProcessGuids or ProcessIDs...
# ActivityID is super specific. No hits outside 4103.
df = df_label.loc[df_label.ActivityID == '{BCCD0404-4290-0000-C0B5-0FD71F20D601}']
#df[df.columns[~df.isnull().all()]].head(100)
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    display(df[df.columns[~df.isnull().all()]][['EventID', 'Hostname', '@timestamp']].groupby('EventID').count().sort_values(by=['@timestamp'], ascending=False).head(20))
# Out:
#          Hostname  @timestamp
# EventID
# 4103.0          1           1

# %%
# ExecutionProcessID doesn't seem to translate outside of the powershell logs.
# ThreatID wouldnt be specific enough... same for ActivityID
# UserID is a maybe..
df = df_label.loc[df_label.Channel == 'Microsoft-Windows-PowerShell/Operational']
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    display(df[df.columns[~df.isnull().all()]][['EventID', 'InstanceId', 'ScriptBlockId', 'Hostname', '@timestamp']].groupby('EventID').count().sort_values(by=['@timestamp'], ascending=False).head(20))
# Out:
#          InstanceId  ScriptBlockId  Hostname  @timestamp
# EventID
# 4103.0            0              0      7750        7750
# 4104.0            0            257       414         414
# 8196.0            0              0        46          46
# 12039.0           0              0        46          46
# 4100.0            0              0        45          45
# 53504.0           0              0        16          16
# 40961.0           0              0        13          13
# 8197.0            0              0        12          12
# 40962.0           0              0        11          11
# 8193.0            0              0         3           3
# 8194.0            3              0         3           3
# 8195.0            0              0         3           3
# 4101.0            0              0         2           2

# %%
df[df.columns[~df.isnull().all()]].head(1)
# Out:
#                    @timestamp  @version            Category  \
# 167  2020-05-02T02:56:19.260Z       1.0  Executing Pipeline
#
#                                       Channel  EventID    EventReceivedTime  \
# 167  Microsoft-Windows-PowerShell/Operational   4103.0  2020-05-01 22:56:19
#
#                EventTime EventType  ExecutionProcessID  \
# 167  2020-05-01 22:56:18      INFO              5944.0
#
#                    Hostname  Keywords  \
# 167  SCRANTON.dmevals.local       0.0
#
# ...

# %% [markdown]
# # Zeek Key Analysis

# %% [markdown]
# - it looks like uid will be sufficient

# %%
# @stream 	@system 	@proc 	ts 	uid 	id_orig_h 	id_orig_p 	id_resp_h 	id_resp_p
df_label.tail(1)
# Out:
#        @timestamp  @version Category Channel  EventID EventReceivedTime  \
# 200899        NaN       NaN      NaN     NaN      NaN               NaN
#
#        EventTime EventType  ExecutionProcessID Hostname IpAddress IpPort  \
# 200899       NaN       NaN                 NaN      NaN       NaN    NaN
#
#         Keywords LogonGuid Message Opcode  OpcodeValue ProviderGuid  \
# 200899       NaN       NaN     NaN    NaN          NaN          NaN
#
#         RecordNumber ServiceName ServiceSid Severity  SeverityValue  \
# 200899           NaN         NaN        NaN      NaN            NaN
#
#        SourceModuleName SourceModuleType SourceName Status TargetDomainName  \
# 200899              NaN              NaN        NaN    NaN              NaN
#
#        TargetUserName  Task  ThreadID TicketEncryptionType TicketOptions  \
# 200899            NaN   NaN       NaN                  NaN           NaN
#
#         TransmittedServices  Version host  port tags TP_Label Action  \
# ...

# %%
# uid is universal enough. doesn't hit on files, x509, or pe
df = df_label.loc[df_label['@stream'].notna()]
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    display(df[df.columns[~df.isnull().all()]].groupby('@stream').count().sort_values(by=['@system'], ascending=False).head(20))
# Out:
#              host  tags  @system  @proc   ts  uid  id_orig_h  id_orig_p  \
# @stream
# conn            0     0      613    613  613  613        613        613
# files           0     0      448    448  448    0          0          0
# ssl             0     0      378    378  378  378        378        378
# x509            0     0      378    378  378    0          0          0
# dce_rpc         0     0      123    123  123  123        123        123
# http           62    62       62     62   62   62         62         62
# dns             0     0       53     53   53   53         53         53
# kerberos        0     0       35     35   35   35         35         35
# dpd             0     0       12     12   12   12         12         12
# smb_files       0     0       12     12   12   12         12         12
# weird           0     0       12     12   12    3          3          3
# smb_mapping     0     0       11     11   11   11         11         11
# ...

# %% [markdown]
# # Sigma

# %%
df_label.query('(EventID=="1") | ExecutionProcessID==3484')
# Out:
#                       @timestamp  @version Category  \
# 215     2020-05-02T03:19:36.611Z       1.0      NaN
# 216     2020-05-02T03:19:36.649Z       1.0      NaN
# 226     2020-05-02T03:08:07.471Z       1.0      NaN
# 229     2020-05-02T03:00:29.194Z       1.0      NaN
# 230     2020-05-02T03:00:30.434Z       1.0      NaN
# ...                          ...       ...      ...
# 198362  2020-05-02T03:19:27.167Z       1.0      NaN
# 198363  2020-05-02T03:19:31.445Z       1.0      NaN
# 198364  2020-05-02T03:19:34.242Z       1.0      NaN
# 198365  2020-05-02T03:19:35.422Z       1.0      NaN
# 198366  2020-05-02T03:19:34.368Z       1.0      NaN
#
#                                      Channel  EventID    EventReceivedTime  \
# 215     Microsoft-Windows-Sysmon/Operational      8.0  2020-05-01 23:19:36
# 216     Microsoft-Windows-Sysmon/Operational      8.0  2020-05-01 23:19:36
# 226     Microsoft-Windows-Sysmon/Operational     23.0  2020-05-01 23:08:07
# ...

# %%
df_label.query('(EventID=="1" & (Image=="*\\whoami.exe" | OriginalFileName=="whoami.exe"))')
# Out:
# Empty DataFrame
# ...

# %%
import pandasql as ps

sql_query = 'SELECT * FROM df_label WHERE (EventID = "1" AND (Image LIKE "%\\whoami.exe" ESCAPE "\" OR OriginalFileName = "whoami.exe"))'

print(ps.sqldf(sql_query, locals()))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/miniconda3/envs/py3msc/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1277                     self.dialect.do_execute(
# -> 1278                         cursor, statement, parameters, context
#    1279                     )
#
# ~/miniconda3/envs/py3msc/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# OperationalError: duplicate column name: SourceProcessGUID
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...
